# %% [markdown]
# # Pipeline de Limpeza de Dados

# %% [markdown]
# ## Importandos as Bibliotecas e os Dados

# %%
# Bibliotecas

import pandas as pd
import unicodedata
import re

# %%
# Dados

df = pd.read_csv("dados.csv")
df1 = df.copy()

# %% [markdown]
# ## Vizualizando o Dataframe

# %%
df1.head()
# Out:
#      ID Cliente    NOME COMPLETO!             E-mail@Principal  idade   \
# 0               1       Ana Silva          ana.silva@yahoo.com      56
# 1               2     Carla Souza                          NaN      69
# 2               3       Ana Costa        ana.costa@hotmail.com      46
# 3               4  Mariana Santos    mariana.santos@bol.com.br      32
# 4               5     MARIA silva    maria.silva@hotmail.com        60
#
#   Data de Nascimento# Telefone/Celular CEP (Código)  \
# 0        Janeiro 1992  (85) 16400-0408     04397312
# 1          10/18/1950    31 87481-2231       123456
# 2                 NaN  (11) 93064-3172    81093-112
# 3          06/08/1976  (11) 42963-8044     80681606
# 4          03/19/2001    11 60767-0256    34867-654
#
#                 Endereço & Cidade Estado-UF          Salário (R$)  \
# 0                             NaN        CE  Salário confidencial
# 1  Rua Principal, 935 - Guarulhos        PA         Não informado
# 2    Rua Central, 633 - Fortaleza        RJ                 12030
# 3   Rua Principal, 630 - Brasília        RS                 12038
# 4     Rua da Paz, 673 - Fortaleza        BA                 14659
#
#   Status_da_Conta Score de Crédito% Produto Favorito* Data da Última Compra  \
# 0        Suspenso               852           Monitor            30/09/2024
# 1           Ativo               517           Monitor            2024-09-13
# 2               A               428           TECLADO            03-13-2024
# 3         Inativo               662          Notebook            04-06-2024
# 4       Bloqueado               375            CAMERA            01-27-2024
#
#   Valor Total Gasto Categoria-Cliente  Unnamed: 16 Obs: Comentários  \
# 0           4495.03              Ouro          NaN              NaN
# 1           6751.27          Diamante          NaN              NaN
# 2           6900.93              Ouro          NaN              NaN
# 3           3743.36           Platina          NaN              NaN
# 4            9077.3              Ouro          NaN              NaN
#
#   Ativo? (S/N) Regional/Zona
# 0        Ativo         norte
# 1            S  centro-oeste
# 2            N  centro-oeste
# 3            N        Centro
# 4            N        Centro

# %%
df1.dtypes
# Out:
#   ID Cliente               int64
# NOME COMPLETO!            object
# E-mail@Principal          object
#  idade                    object
# Data de Nascimento#       object
# Telefone/Celular          object
# CEP (Código)              object
# Endereço & Cidade         object
# Estado-UF                 object
# Salário (R$)              object
# Status_da_Conta           object
# Score de Crédito%         object
# Produto Favorito*         object
# Data da Última Compra     object
# Valor Total Gasto         object
# Categoria-Cliente         object
# Unnamed: 16              float64
# Obs: Comentários          object
# Ativo? (S/N)              object
# Regional/Zona             object
# dtype: object

# %%
df1.shape
# Out:
# (52500, 20)

# %%
df1.describe
# Out:
# <bound method NDFrame.describe of          ID Cliente      NOME COMPLETO!                E-mail@Principal  \
# 0                   1         Ana Silva             ana.silva@yahoo.com
# 1                   2       Carla Souza                             NaN
# 2                   3         Ana Costa           ana.costa@hotmail.com
# 3                   4    Mariana Santos       mariana.santos@bol.com.br
# 4                   5       MARIA silva       maria.silva@hotmail.com
# ...               ...               ...                             ...
# 52495           26846    PAULO ferreira    paulo.ferreira@outlook.com
# 52496           45552    Patricia Silva     patricia.silva@uol.com.br
# 52497           25412        João Alves           joão.alves@uol.com.br
# 52498           44726       Lucia Gomes           lucia.gomes@gmail.com
# 52499           30012  Carlos Rodrigues    carlos.rodrigues@outlook.com
#
#        idade  Data de Nascimento# Telefone/Celular CEP (Código)  \
# 0          56        Janeiro 1992  (85) 16400-0408     04397312
# 1          69          10/18/1950    31 87481-2231       123456
# 2          46                 NaN  (11) 93064-3172    81093-112
# 3          32          06/08/1976  (11) 42963-8044     80681606
# 4          60          03/19/2001    11 60767-0256    34867-654
# ...       ...                 ...              ...          ...
# 52495      38          09/21/1996  (11) 02698-1177     55227309
# 52496      53          11/09/1968  (11) 99999-9999    05529-465
# 52497      18          06/09/1968              123     60427184
# 52498      75          15/02/1990      11587515945     71609249
# 52499      35          01/16/1970    11 58549-1317    02218-308
#
#                           Endereço & Cidade Estado-UF          Salário (R$)  \
# 0                                       NaN        CE  Salário confidencial
# 1            Rua Principal, 935 - Guarulhos        PA         Não informado
# 2              Rua Central, 633 - Fortaleza        RJ                 12030
# 3             Rua Principal, 630 - Brasília        RS                 12038
# 4               Rua da Paz, 673 - Fortaleza        BA                 14659
# ...                                     ...       ...                   ...
# 52495  Rua das Flores, 941 - Rio de Janeiro        SP                 14486
# 52496     Rua Central, 860 - Rio de Janeiro        SP              3,500.50
# 52497             Rua da Paz, 51 - Brasília        PE                  6930
# 52498          Rua da Paz, 2 - Porto Alegre        SP                  9779
# 52499          Rua das Flores, 372 - Manaus        RS                  8644
#
#       Status_da_Conta Score de Crédito% Produto Favorito*  \
# 0            Suspenso               852           Monitor
# 1               Ativo               517           Monitor
# 2                   A               428           TECLADO
# 3             Inativo               662          Notebook
# 4           Bloqueado               375            CAMERA
# ...               ...               ...               ...
# 52495        Suspenso               550                TV
# 52496         Inativo               836          Notebook
# 52497       Bloqueado               866           Teclado
# 52498           Ativo             Baixo            Camera
# 52499       Bloqueado               381             Mouse
#
#       Data da Última Compra Valor Total Gasto Categoria-Cliente  Unnamed: 16  \
# 0                30/09/2024           4495.03              Ouro          NaN
# 1                2024-09-13           6751.27          Diamante          NaN
# 2                03-13-2024           6900.93              Ouro          NaN
# 3                04-06-2024           3743.36           Platina          NaN
# 4                01-27-2024            9077.3              Ouro          NaN
# ...                     ...               ...               ...          ...
# 52495            13/07/2024           2090.78            Bronze          NaN
# 52496            2024/01/15            R$2500            Bronze          NaN
# 52497            10-28-2024            718.06            Bronze          NaN
# 52498            12-30-2024           1218.89              Ouro          NaN
# 52499            09/09/2024           3468.76           Platina          NaN
#
#          Obs: Comentários Ativo? (S/N) Regional/Zona
# 0                     NaN        Ativo         norte
# 1                     NaN            S  centro-oeste
# 2                     NaN            N  centro-oeste
# 3                     NaN            N        Centro
# 4                     NaN            N        Centro
# ...                   ...          ...           ...
# 52495    CLIENTE EXIGENTE            N           Sul
# 52496  Registro duplicado            S        Centro
# 52497  Registro duplicado            N         norte
# 52498  Registro duplicado            S         Norte
# 52499                 NaN            N           SUL
#
# [52500 rows x 20 columns]>

# %%
df1.isnull().sum()
# Out:
#   ID Cliente                 0
# NOME COMPLETO!               0
# E-mail@Principal          7888
#  idade                    2164
# Data de Nascimento#       2575
# Telefone/Celular          2097
# CEP (Código)              2163
# Endereço & Cidade         5220
# Estado-UF                 1402
# Salário (R$)              2073
# Status_da_Conta           1046
# Score de Crédito%         3039
# Produto Favorito*         6230
# Data da Última Compra     3346
# Valor Total Gasto         2105
# Categoria-Cliente         1162
# Unnamed: 16              52500
# Obs: Comentários         40034
# Ativo? (S/N)              1096
# Regional/Zona             2677
# dtype: int64

# %% [markdown]
# ## Padronizando os Dados

# %% [markdown]
# - remover espaços
# - normalizar acentos
# - transformar para minúsculas
# - padronizar datas
# - converter tipos
# - normalizar categorias

# %% [markdown]
# ### Padronização dos Nomes das Colunas

# %%
# função de padronização das colunas
def padronizar_colunas(colunas):
    novas_colunas = []
    for col in colunas:
        # remove acentos
        col = unicodedata.normalize('NFKD', col).encode('ascii', 'ignore').decode('utf-8')
        # deixa tudo em minúsculas
        col = col.lower()
        # remove caracteres especiais
        col = re.sub(r'[^a-z0-9_]', '_', col)
        # remove underscores duplicados
        col = re.sub(r'_+', '_', col)
        # remove underscore no começo ou fim
        col = col.strip('_')
        novas_colunas.append(col)
    return novas_colunas

df1.columns = padronizar_colunas(df1.columns)

# %%
df1.head()
# Out:
#    id_cliente   nome_completo             e_mail_principal idade  \
# 0           1       Ana Silva          ana.silva@yahoo.com    56
# 1           2     Carla Souza                          NaN    69
# 2           3       Ana Costa        ana.costa@hotmail.com    46
# 3           4  Mariana Santos    mariana.santos@bol.com.br    32
# 4           5     MARIA silva    maria.silva@hotmail.com      60
#
#   data_de_nascimento telefone_celular cep_codigo  \
# 0       Janeiro 1992  (85) 16400-0408   04397312
# 1         10/18/1950    31 87481-2231     123456
# 2                NaN  (11) 93064-3172  81093-112
# 3         06/08/1976  (11) 42963-8044   80681606
# 4         03/19/2001    11 60767-0256  34867-654
#
#                   endereco_cidade estado_uf             salario_r  \
# 0                             NaN        CE  Salário confidencial
# 1  Rua Principal, 935 - Guarulhos        PA         Não informado
# 2    Rua Central, 633 - Fortaleza        RJ                 12030
# 3   Rua Principal, 630 - Brasília        RS                 12038
# 4     Rua da Paz, 673 - Fortaleza        BA                 14659
#
#   status_da_conta score_de_credito produto_favorito data_da_ultima_compra  \
# 0        Suspenso              852          Monitor            30/09/2024
# 1           Ativo              517          Monitor            2024-09-13
# 2               A              428          TECLADO            03-13-2024
# 3         Inativo              662         Notebook            04-06-2024
# 4       Bloqueado              375           CAMERA            01-27-2024
#
#   valor_total_gasto categoria_cliente  unnamed_16 obs_comentarios ativo_s_n  \
# 0           4495.03              Ouro         NaN             NaN     Ativo
# 1           6751.27          Diamante         NaN             NaN         S
# 2           6900.93              Ouro         NaN             NaN         N
# 3           3743.36           Platina         NaN             NaN         N
# 4            9077.3              Ouro         NaN             NaN         N
#
#   regional_zona
# 0         norte
# 1  centro-oeste
# 2  centro-oeste
# 3        Centro
# 4        Centro

# %%
# Renomeando colunas específicas

df1 = df1.rename(columns={
    "e_mail_principal": "email",
    "cep_codigo": "cep",
    "endereco_cidade": "endereco",
    "salario_r": "salario",
    "ativo_s_n": "ativo"
})

# %%
df1.head()
# Out:
#    id_cliente   nome_completo                        email idade  \
# 0           1       Ana Silva          ana.silva@yahoo.com    56
# 1           2     Carla Souza                          NaN    69
# 2           3       Ana Costa        ana.costa@hotmail.com    46
# 3           4  Mariana Santos    mariana.santos@bol.com.br    32
# 4           5     MARIA silva    maria.silva@hotmail.com      60
#
#   data_de_nascimento telefone_celular        cep  \
# 0       Janeiro 1992  (85) 16400-0408   04397312
# 1         10/18/1950    31 87481-2231     123456
# 2                NaN  (11) 93064-3172  81093-112
# 3         06/08/1976  (11) 42963-8044   80681606
# 4         03/19/2001    11 60767-0256  34867-654
#
#                          endereco estado_uf               salario  \
# 0                             NaN        CE  Salário confidencial
# 1  Rua Principal, 935 - Guarulhos        PA         Não informado
# 2    Rua Central, 633 - Fortaleza        RJ                 12030
# 3   Rua Principal, 630 - Brasília        RS                 12038
# 4     Rua da Paz, 673 - Fortaleza        BA                 14659
#
#   status_da_conta score_de_credito produto_favorito data_da_ultima_compra  \
# 0        Suspenso              852          Monitor            30/09/2024
# 1           Ativo              517          Monitor            2024-09-13
# 2               A              428          TECLADO            03-13-2024
# 3         Inativo              662         Notebook            04-06-2024
# 4       Bloqueado              375           CAMERA            01-27-2024
#
#   valor_total_gasto categoria_cliente  unnamed_16 obs_comentarios  ativo  \
# 0           4495.03              Ouro         NaN             NaN  Ativo
# 1           6751.27          Diamante         NaN             NaN      S
# 2           6900.93              Ouro         NaN             NaN      N
# 3           3743.36           Platina         NaN             NaN      N
# 4            9077.3              Ouro         NaN             NaN      N
#
#   regional_zona
# 0         norte
# 1  centro-oeste
# 2  centro-oeste
# 3        Centro
# 4        Centro

# %% [markdown]
# ### Padronização de Colunas Diversas

# %%
df1.head()
# Out:
#    id_cliente   nome_completo                        email idade  \
# 0           1       Ana Silva          ana.silva@yahoo.com    56
# 1           2     Carla Souza                          NaN    69
# 2           3       Ana Costa        ana.costa@hotmail.com    46
# 3           4  Mariana Santos    mariana.santos@bol.com.br    32
# 4           5     MARIA silva    maria.silva@hotmail.com      60
#
#   data_de_nascimento telefone_celular        cep  \
# 0       Janeiro 1992  (85) 16400-0408   04397312
# 1         10/18/1950    31 87481-2231     123456
# 2                NaN  (11) 93064-3172  81093-112
# 3         06/08/1976  (11) 42963-8044   80681606
# 4         03/19/2001    11 60767-0256  34867-654
#
#                          endereco estado_uf               salario  \
# 0                             NaN        CE  Salário confidencial
# 1  Rua Principal, 935 - Guarulhos        PA         Não informado
# 2    Rua Central, 633 - Fortaleza        RJ                 12030
# 3   Rua Principal, 630 - Brasília        RS                 12038
# 4     Rua da Paz, 673 - Fortaleza        BA                 14659
#
#   status_da_conta score_de_credito produto_favorito data_da_ultima_compra  \
# 0        Suspenso              852          Monitor            30/09/2024
# 1           Ativo              517          Monitor            2024-09-13
# 2               A              428          TECLADO            03-13-2024
# 3         Inativo              662         Notebook            04-06-2024
# 4       Bloqueado              375           CAMERA            01-27-2024
#
#   valor_total_gasto categoria_cliente  unnamed_16 obs_comentarios  ativo  \
# 0           4495.03              Ouro         NaN             NaN  Ativo
# 1           6751.27          Diamante         NaN             NaN      S
# 2           6900.93              Ouro         NaN             NaN      N
# 3           3743.36           Platina         NaN             NaN      N
# 4            9077.3              Ouro         NaN             NaN      N
#
#   regional_zona
# 0         norte
# 1  centro-oeste
# 2  centro-oeste
# 3        Centro
# 4        Centro

# %%
cols = ['endereco', 'status_da_conta', 'produto_favorito', 'categoria_cliente', 'ativo', 'regional_zona']

for col in cols:
    df1[col] = (
        df1[col]
        .str.normalize('NFKD')
        .str.encode('ascii', errors='ignore')
        .str.decode('utf-8')
        .str.lower()
        .str.strip()
        .str.replace(r'\s+', ' ', regex=True)
    )

# %%
df1.head()
# Out:
#    id_cliente   nome_completo                        email idade  \
# 0           1       Ana Silva          ana.silva@yahoo.com    56
# 1           2     Carla Souza                          NaN    69
# 2           3       Ana Costa        ana.costa@hotmail.com    46
# 3           4  Mariana Santos    mariana.santos@bol.com.br    32
# 4           5     MARIA silva    maria.silva@hotmail.com      60
#
#   data_de_nascimento telefone_celular        cep  \
# 0       Janeiro 1992  (85) 16400-0408   04397312
# 1         10/18/1950    31 87481-2231     123456
# 2                NaN  (11) 93064-3172  81093-112
# 3         06/08/1976  (11) 42963-8044   80681606
# 4         03/19/2001    11 60767-0256  34867-654
#
#                          endereco estado_uf               salario  \
# 0                             NaN        CE  Salário confidencial
# 1  rua principal, 935 - guarulhos        PA         Não informado
# 2    rua central, 633 - fortaleza        RJ                 12030
# 3   rua principal, 630 - brasilia        RS                 12038
# 4     rua da paz, 673 - fortaleza        BA                 14659
#
#   status_da_conta score_de_credito produto_favorito data_da_ultima_compra  \
# 0        suspenso              852          monitor            30/09/2024
# 1           ativo              517          monitor            2024-09-13
# 2               a              428          teclado            03-13-2024
# 3         inativo              662         notebook            04-06-2024
# 4       bloqueado              375           camera            01-27-2024
#
#   valor_total_gasto categoria_cliente  unnamed_16 obs_comentarios  ativo  \
# 0           4495.03              ouro         NaN             NaN  ativo
# 1           6751.27          diamante         NaN             NaN      s
# 2           6900.93              ouro         NaN             NaN      n
# 3           3743.36           platina         NaN             NaN      n
# 4            9077.3              ouro         NaN             NaN      n
#
#   regional_zona
# 0         norte
# 1  centro-oeste
# 2  centro-oeste
# 3        centro
# 4        centro

# %% [markdown]
# ### Padronização Específica por Coluna

# %% [markdown]
# #### Padronização da Coluna "nome_completo"

# %%
df1["nome_completo"].tail()
# Out:
# 52495      PAULO ferreira
# 52496      Patricia Silva
# 52497          João Alves
# 52498         Lucia Gomes
# 52499    Carlos Rodrigues
# Name: nome_completo, dtype: object

# %%
df1['nome_completo'] = df1['nome_completo'].str.title()

# %%
df1['nome_completo'] = df1['nome_completo'].str.replace(
    r'^(sr\.?|sra\.?|srta\.?|dr\.?|dra\.?|prof\.?|profa\.?)\s*',
    '',
    regex=True,
    flags=re.IGNORECASE
)

# %%
df1["nome_completo"].tail()
# Out:
# 52495      Paulo Ferreira
# 52496      Patricia Silva
# 52497          João Alves
# 52498         Lucia Gomes
# 52499    Carlos Rodrigues
# Name: nome_completo, dtype: object

# %%
# Criando a coluna "nome_limpo" (para deduplicação)

df1['nome_limpo'] = (
    df1['nome_completo']
    .str.normalize('NFKD')
    .str.encode('ascii', errors='ignore')
    .str.decode('utf-8')
    .str.lower()
    .str.strip()
    .str.replace(r'\s+', ' ', regex=True)
)

colunas = list(df1.columns)

# Alterando a posição da coluna nome_limpo

idx = colunas.index('nome_completo')
colunas.remove('nome_limpo')
colunas.insert(idx + 1, 'nome_limpo')
df1 = df1[colunas]

# %%
df1.head()
# Out:
#    id_cliente   nome_completo      nome_limpo                        email  \
# 0           1       Ana Silva       ana silva          ana.silva@yahoo.com
# 1           2     Carla Souza     carla souza                          NaN
# 2           3       Ana Costa       ana costa        ana.costa@hotmail.com
# 3           4  Mariana Santos  mariana santos    mariana.santos@bol.com.br
# 4           5     Maria Silva     maria silva    maria.silva@hotmail.com
#
#   idade data_de_nascimento telefone_celular        cep  \
# 0    56       Janeiro 1992  (85) 16400-0408   04397312
# 1    69         10/18/1950    31 87481-2231     123456
# 2    46                NaN  (11) 93064-3172  81093-112
# 3    32         06/08/1976  (11) 42963-8044   80681606
# 4    60         03/19/2001    11 60767-0256  34867-654
#
#                          endereco estado_uf  ... status_da_conta  \
# 0                             NaN        CE  ...        suspenso
# 1  rua principal, 935 - guarulhos        PA  ...           ativo
# 2    rua central, 633 - fortaleza        RJ  ...               a
# 3   rua principal, 630 - brasilia        RS  ...         inativo
# 4     rua da paz, 673 - fortaleza        BA  ...       bloqueado
#
#   score_de_credito produto_favorito data_da_ultima_compra valor_total_gasto  \
# 0              852          monitor            30/09/2024           4495.03
# 1              517          monitor            2024-09-13           6751.27
# 2              428          teclado            03-13-2024           6900.93
# 3              662         notebook            04-06-2024           3743.36
# 4              375           camera            01-27-2024            9077.3
#
#   categoria_cliente unnamed_16  obs_comentarios  ativo regional_zona
# 0              ouro        NaN              NaN  ativo         norte
# 1          diamante        NaN              NaN      s  centro-oeste
# 2              ouro        NaN              NaN      n  centro-oeste
# 3           platina        NaN              NaN      n        centro
# 4              ouro        NaN              NaN      n        centro
#
# [5 rows x 21 columns]

# %% [markdown]
# #### Padronização da Coluna "email"

# %% [markdown]
# **O que pode ser feito com segurança**
#
# - Remover espaços extras
# - Converter para minúsculas
# - Remover quebras de linha
# - Tratar casos óbvios de sujeira (“;”, vírgulas, espaços no meio)
# - Validar formato básico (opcional)
#
# **O que não deve ser feito**
#
# - Não remover pontos antes do @ (ex.: joao.silva@gmail.com ≠ joaosilva@gmail.com)
# - Não remover sinais como “+” (ex.: joao+teste@gmail.com é válido)
# - Não tentar “corrigir” domínios manualmente
# - Não aplicar normalização de acentos (e‑mail não deve ter acentos, mas se tiver, é melhor sinalizar do que alterar)

# %%
df1.tail()
# Out:
#        id_cliente     nome_completo        nome_limpo  \
# 52495       26846    Paulo Ferreira    paulo ferreira
# 52496       45552    Patricia Silva    patricia silva
# 52497       25412        João Alves        joao alves
# 52498       44726       Lucia Gomes       lucia gomes
# 52499       30012  Carlos Rodrigues  carlos rodrigues
#
#                                 email idade data_de_nascimento  \
# 52495    paulo.ferreira@outlook.com      38         09/21/1996
# 52496     patricia.silva@uol.com.br      53         11/09/1968
# 52497           joão.alves@uol.com.br    18         06/09/1968
# 52498           lucia.gomes@gmail.com    75         15/02/1990
# 52499    carlos.rodrigues@outlook.com    35         01/16/1970
#
#       telefone_celular        cep                              endereco  \
# 52495  (11) 02698-1177   55227309  rua das flores, 941 - rio de janeiro
# 52496  (11) 99999-9999  05529-465     rua central, 860 - rio de janeiro
# 52497              123   60427184             rua da paz, 51 - brasilia
# 52498      11587515945   71609249          rua da paz, 2 - porto alegre
# 52499    11 58549-1317  02218-308          rua das flores, 372 - manaus
#
#       estado_uf  ... status_da_conta score_de_credito produto_favorito  \
# 52495        SP  ...        suspenso              550               tv
# 52496        SP  ...         inativo              836         notebook
# 52497        PE  ...       bloqueado              866          teclado
# 52498        SP  ...           ativo            Baixo           camera
# 52499        RS  ...       bloqueado              381            mouse
#
#       data_da_ultima_compra valor_total_gasto categoria_cliente unnamed_16  \
# 52495            13/07/2024           2090.78            bronze        NaN
# 52496            2024/01/15            R$2500            bronze        NaN
# 52497            10-28-2024            718.06            bronze        NaN
# 52498            12-30-2024           1218.89              ouro        NaN
# 52499            09/09/2024           3468.76           platina        NaN
#
#           obs_comentarios ativo regional_zona
# 52495    CLIENTE EXIGENTE     n           sul
# 52496  Registro duplicado     s        centro
# 52497  Registro duplicado     n         norte
# 52498  Registro duplicado     s         norte
# 52499                 NaN     n           sul
#
# [5 rows x 21 columns]

# %%
df1['email'] = (
    df1['email']
    .astype(str)
    .str.strip()
    .str.lower()
    .str.replace(r'\s+', '', regex=True)
    .str.replace(r'[;,]+', '', regex=True)
)

# %%
import numpy as np

def limpar_e_validar_email(e):
    e = str(e).strip().lower()
    e = e.replace(" ", "")  # remove espaços internos

    # valores claramente inválidos
    if e in ["", "nao_informado", "não_informado", "nao informado", "none", "null"]:
        return np.nan

    # sem arroba
    if '@' not in e:
        return np.nan

    usuario, dominio = e.split('@', 1)

    # usuario vazio → caso @dominio.com
    if usuario == "":
        return np.nan

    # dominio sem ponto
    if '.' not in dominio:
        return np.nan

    return e

df1['email'] = df1['email'].apply(limpar_e_validar_email)

# %%
df1.tail()
# Out:
#        id_cliente     nome_completo        nome_limpo  \
# 52495       26846    Paulo Ferreira    paulo ferreira
# 52496       45552    Patricia Silva    patricia silva
# 52497       25412        João Alves        joao alves
# 52498       44726       Lucia Gomes       lucia gomes
# 52499       30012  Carlos Rodrigues  carlos rodrigues
#
#                               email idade data_de_nascimento telefone_celular  \
# 52495    paulo.ferreira@outlook.com    38         09/21/1996  (11) 02698-1177
# 52496     patricia.silva@uol.com.br    53         11/09/1968  (11) 99999-9999
# 52497         joão.alves@uol.com.br    18         06/09/1968              123
# 52498         lucia.gomes@gmail.com    75         15/02/1990      11587515945
# 52499  carlos.rodrigues@outlook.com    35         01/16/1970    11 58549-1317
#
#              cep                              endereco estado_uf  ...  \
# 52495   55227309  rua das flores, 941 - rio de janeiro        SP  ...
# 52496  05529-465     rua central, 860 - rio de janeiro        SP  ...
# 52497   60427184             rua da paz, 51 - brasilia        PE  ...
# 52498   71609249          rua da paz, 2 - porto alegre        SP  ...
# 52499  02218-308          rua das flores, 372 - manaus        RS  ...
#
#       status_da_conta score_de_credito produto_favorito data_da_ultima_compra  \
# 52495        suspenso              550               tv            13/07/2024
# 52496         inativo              836         notebook            2024/01/15
# 52497       bloqueado              866          teclado            10-28-2024
# 52498           ativo            Baixo           camera            12-30-2024
# 52499       bloqueado              381            mouse            09/09/2024
#
#       valor_total_gasto categoria_cliente unnamed_16     obs_comentarios  \
# 52495           2090.78            bronze        NaN    CLIENTE EXIGENTE
# 52496            R$2500            bronze        NaN  Registro duplicado
# 52497            718.06            bronze        NaN  Registro duplicado
# 52498           1218.89              ouro        NaN  Registro duplicado
# 52499           3468.76           platina        NaN                 NaN
#
#       ativo regional_zona
# 52495     n           sul
# 52496     s        centro
# 52497     n         norte
# 52498     s         norte
# 52499     n           sul
#
# [5 rows x 21 columns]

# %% [markdown]
# #### Padronização da Coluna "idade"

# %%
df1.head()
# Out:
#    id_cliente   nome_completo      nome_limpo                      email  \
# 0           1       Ana Silva       ana silva        ana.silva@yahoo.com
# 1           2     Carla Souza     carla souza                        NaN
# 2           3       Ana Costa       ana costa      ana.costa@hotmail.com
# 3           4  Mariana Santos  mariana santos  mariana.santos@bol.com.br
# 4           5     Maria Silva     maria silva    maria.silva@hotmail.com
#
#   idade data_de_nascimento telefone_celular        cep  \
# 0    56       Janeiro 1992  (85) 16400-0408   04397312
# 1    69         10/18/1950    31 87481-2231     123456
# 2    46                NaN  (11) 93064-3172  81093-112
# 3    32         06/08/1976  (11) 42963-8044   80681606
# 4    60         03/19/2001    11 60767-0256  34867-654
#
#                          endereco estado_uf  ... status_da_conta  \
# 0                             NaN        CE  ...        suspenso
# 1  rua principal, 935 - guarulhos        PA  ...           ativo
# 2    rua central, 633 - fortaleza        RJ  ...               a
# 3   rua principal, 630 - brasilia        RS  ...         inativo
# 4     rua da paz, 673 - fortaleza        BA  ...       bloqueado
#
#   score_de_credito produto_favorito data_da_ultima_compra valor_total_gasto  \
# 0              852          monitor            30/09/2024           4495.03
# 1              517          monitor            2024-09-13           6751.27
# 2              428          teclado            03-13-2024           6900.93
# 3              662         notebook            04-06-2024           3743.36
# 4              375           camera            01-27-2024            9077.3
#
#   categoria_cliente unnamed_16  obs_comentarios  ativo regional_zona
# 0              ouro        NaN              NaN  ativo         norte
# 1          diamante        NaN              NaN      s  centro-oeste
# 2              ouro        NaN              NaN      n  centro-oeste
# 3           platina        NaN              NaN      n        centro
# 4              ouro        NaN              NaN      n        centro
#
# [5 rows x 21 columns]

# %%
df1.dtypes
# Out:
# id_cliente                 int64
# nome_completo             object
# nome_limpo                object
# email                     object
# idade                     object
# data_de_nascimento        object
# telefone_celular          object
# cep                       object
# endereco                  object
# estado_uf                 object
# salario                   object
# status_da_conta           object
# score_de_credito          object
# produto_favorito          object
# data_da_ultima_compra     object
# valor_total_gasto         object
# categoria_cliente         object
# unnamed_16               float64
# obs_comentarios           object
# ativo                     object
# regional_zona             object
# dtype: object

# %%
df1['idade'] = pd.to_numeric(df1['idade'], errors='coerce').astype('float64')
pd.set_option('display.float_format', '{:.0f}'.format)
df1.loc[(df1['idade'] < 0) | (df1['idade'] > 100), 'idade'] = np.nan

# %%
df1.sample(60)
# Out:
#        id_cliente       nome_completo          nome_limpo  \
# 40215       40216         Pedro Gomes         pedro gomes
# 961           962     Claudia Ribeiro     claudia ribeiro
# 291           292     Marcos Ferreira     marcos ferreira
# 3671         3672         André Alves         andre alves
# 8114         8115       Ricardo Costa       ricardo costa
# 15125       15126       Rafael Santos       rafael santos
# 17341       17342     Pedro Rodrigues     pedro rodrigues
# 12362       12363      Bruno Oliveira      bruno oliveira
# 30199       30200    Rafael Rodrigues    rafael rodrigues
# 3080         3081         Bruno Gomes         bruno gomes
# 23067       23068          João Silva          joao silva
# 37197       37198       Juliana Gomes       juliana gomes
# 52280       33409     Ricardo Pereira     ricardo pereira
# 12785       12786       Marcos Santos       marcos santos
# 41725       41726     Marcos Alves123     marcos alves123
# 37758       37759      João Rodrigues      joao rodrigues
# 33618       33619       Ricardo Souza       ricardo souza
# 25501       25502         Lucia Gomes         lucia gomes
# 38600       38601    Cristina Ribeiro    cristina ribeiro
# 52023       23177     Claudia Pereira     claudia pereira
# 30686       30687    Paulo Ferreira        paulo ferreira
# 28982       28983        Marcos Silva        marcos silva
# 18229       18230        Ana Oliveira        ana oliveira
# 3918         3919      Carlos Ribeiro      carlos ribeiro
# 29245       29246     Rafael Ferreira     rafael ferreira
# 15088       15089         Lucia Silva         lucia silva
# 10407       10408  Fernanda Rodrigues  fernanda rodrigues
# 42297       42298        Pedro Santos        pedro santos
# 8197         8198       Pedro Pereira       pedro pereira
# 34181       34182         Bruno Costa         bruno costa
# 37740       37741         Carla Souza         carla souza
# 26798       26799        Marcos Gomes        marcos gomes
# 29147       29148         Paulo Gomes         paulo gomes
# 47174       47175         Pedro Gomes         pedro gomes
# 44909       44910   Marcos De Pereira   marcos de pereira
# 32131       32132    Mariana Ferreira    mariana ferreira
# 26999       27000     Ricardo Pereira     ricardo pereira
# 17009       17010      Carla Alves123      carla alves123
# 6702         6703     Fernando Santos     fernando santos
# 17212       17213         André Gomes         andre gomes
# 25799       25800       Claudia Alves       claudia alves
# 34688       34689       Bruno Pereira       bruno pereira
# 46515       46516    Claudia Oliveira    claudia oliveira
# 47035       47036         Carla Costa         carla costa
# 6566         6567         Paulo Alves         paulo alves
# 3624         3625       Mariana Gomes       mariana gomes
# 32012       32013   Patricia Ferreira   patricia ferreira
# 12326       12327      Bruno Ferreira      bruno ferreira
# 15100       15101    Patricia Ribeiro    patricia ribeiro
# 18122       18123       Bruno Pereira       bruno pereira
# 9903         9904      Rafael Ribeiro      rafael ribeiro
# 51427        2281         Pedro Gomes         pedro gomes
# 11713       11714        Mariana Lima        mariana lima
# 6075         6076      Fernando Souza      fernando souza
# 39402       39403   Ricardo Rodrigues   ricardo rodrigues
# 37934       37935         Ana Ribeiro         ana ribeiro
# 27287       27288     Maria Rodrigues     maria rodrigues
# 37918       37919      Bruno Oliveira      bruno oliveira
# 20933       20934  Fernando Rodrigues  fernando rodrigues
# 49568       49569         Carla Gomes         carla gomes
#
#                                email  idade data_de_nascimento  \
# 40215         pedro.gomes@bol.com.br     60         05/20/1970
# 961       claudia.ribeiro@bol.com.br    NaN         12/05/1955
# 291      marcos.ferreira@outlook.com     59         06/24/1950
# 3671         andré.alves@outlook.com     55         04/22/1967
# 8114                             NaN     41         06/15/1978
# 15125        rafael.santos@yahoo.com     68         05/25/1968
# 17341    pedro.rodrigues@outlook.com     77      Não informado
# 12362           acentuação@email.com     54         09/03/1987
# 30199   rafael.rodrigues@hotmail.com     59                NaN
# 3080           bruno.gomes@gmail.com     73       Janeiro 1992
# 23067           joão.silva@yahoo.com     73         05/19/1975
# 37197        juliana.gomes@gmail.com    NaN           03-07-88
# 52280    ricardo.pereira@hotmail.com     22         11/25/1999
# 12785                            NaN    NaN       Janeiro 1992
# 41725      marcos.alves123@yahoo.com     59         07/12/1986
# 37758      joão.rodrigues@uol.com.br    NaN         11/23/1981
# 33618                            NaN     27         12/28/1972
# 25501                            NaN     37         01/12/1969
# 38600   cristina.ribeiro@outlook.com     32         15/02/1990
# 52023      claudia.pereira@gmail.com     50         02/12/1994
# 30686       paulo.ferreira@yahoo.com     70         07/10/1992
# 28982         marcos.silva@gmail.com     52         04/10/1964
# 18229                            NaN     76         07/24/1952
# 3918       carlos.ribeiro@bol.com.br     77         12/20/1986
# 29245      rafael.ferreira@gmail.com     53                NaN
# 15088         lucia.silva@bol.com.br     28         1985-12-25
# 10407  fernanda.rodrigues@bol.com.br     41         32/13/1980
# 42297        pedro.santos@uol.com.br     32         09/11/1969
# 8197       pedro.pereira@outlook.com     64         11/20/1961
# 34181     sr..bruno.costa@bol.com.br     72         12/21/1978
# 37740          carla.souza@yahoo.com     37         03/12/1990
# 26798                            NaN     50         06/10/1996
# 29147          paulo.gomes@gmail.com     18         15/02/1990
# 47174         pedro.gomes@bol.com.br     43         02/12/1983
# 44909   marcos.de.pereira@bol.com.br     49         01/02/2001
# 32131    mariana.ferreira@bol.com.br     58         04/01/1972
# 26999      ricardo.pereira@yahoo.com     63         08/09/1983
# 17009     carla.alves123@hotmail.com     56         11/26/1956
# 6702       fernando.santos@yahoo.com     76         01/08/1981
# 17212         andré.gomes@uol.com.br     69         10/25/1985
# 25799       claudia.alves@uol.com.br     72         06/18/1959
# 34688  sr..bruno.pereira@outlook.com     52         11/15/1961
# 46515   claudia.oliveira@hotmail.com     19         06/19/1956
# 47035          carla.costa@yahoo.com    NaN         08/17/1990
# 6566         paulo.alves@hotmail.com    NaN         12/26/1990
# 3624        mariana.gomes@bol.com.br     51         06/06/1971
# 32012                            NaN     40                NaN
# 12326     bruno.ferreira@outlook.com     48         01/20/1952
# 15100   patricia.ribeiro@outlook.com    NaN         02/13/1989
# 18122            maiusculo@email.com    NaN                NaN
# 9903                             NaN     23         07/05/1950
# 51427         pedro.gomes@uol.com.br     42         12/06/1997
# 11713       mariana.lima@outlook.com     63         12/24/1998
# 6075               espacos@email.com     67                NaN
# 39402             usuario@@duplo.com     72         01/12/1953
# 37934         ana.ribeiro@uol.com.br     60         03/02/1981
# 27287     maria.rodrigues@uol.com.br     45         01/19/1959
# 37918                            NaN     42         04/23/1953
# 20933                            NaN    NaN         07/04/1995
# 49568                            NaN     33         07/06/1982
#
#         telefone_celular                cep  \
# 40215        31891227553           92807708
# 961      (11) 64943-0002          34554-338
# 291        21 93276-1197          14399-871
# 3671       21 01509-4130           34082334
# 8114         47629299229           36528012
# 15125    (47) 32473-4680           08303289
# 17341      21 76672-6972           22525775
# 12362        11999999999             123456
# 30199        85566669926           10249068
# 3080       11 40502-5317          87788-338
# 23067      11 43037-3309           02643391
# 37197      21 10889-2507          72355-693
# 52280        47294451778           80415998
# 12785    (85) 59160-7251          07282-909
# 41725        21243614137          06951-700
# 37758        47426411376          49186-944
# 33618    (11) 78603-3885           19377320
# 25501                123           19077323
# 38600    (85) 78237-5664           47003449
# 52023        21684264047           04047945
# 30686      31 26537-4624           79405460
# 28982     11 9 9999-9999           56605327
# 18229      31 58878-2469          94747-897
# 3918       47 86424-7872  CEP não informado
# 29245      47 75568-7333          00000-000
# 15088      21 58434-1277           74168823
# 10407    (47) 58156-9100           05176079
# 42297      21 57451-5200             123456
# 8197     (85) 31622-5423          19782-759
# 34181      85 46940-4578         12.345-678
# 37740    (11) 99999-9999           78298424
# 26798      21 05553-7206           01064651
# 29147      21 33220-3174           63995130
# 47174      85 01880-8590          09414-728
# 44909  +55 11 99999-9999                NaN
# 32131      85 78206-8431           46840437
# 26999    (11) 89731-1092           75833210
# 17009    (31) 21176-8154           14274768
# 6702         85156737161           88114900
# 17212     11 9 9999-9999          41561-050
# 25799      11 13753-1637           60624948
# 34688      47 38564-8560          95414-080
# 46515      85 89386-3354           79086311
# 47035        31013554527          98292-785
# 6566     (85) 69402-8950           20745251
# 3624                 NaN           35455258
# 32012    (85) 02575-6875           34440869
# 12326        11691126855           66229094
# 15100        11945744331          25653-531
# 18122      31 04527-2766           12566701
# 9903       31 61136-4729          85087-824
# 51427      11 50776-4540          36964-342
# 11713      21 70655-8843           84143816
# 6075   telefone inválido           77464113
# 39402      47 68949-5885           30731993
# 37934                NaN          00000-000
# 27287      21 67723-5247           60797603
# 37918        11585589427           05507797
# 20933      11 78714-2244           26050802
# 49568      85 51200-3299          72617-574
#
#                                    endereco       estado_uf  ...  \
# 40215     rua central, 952 - rio de janeiro             NaN  ...
# 961            rua central, 599 - guarulhos              CE  ...
# 291              rua da paz, 593 - brasilia              SP  ...
# 3671           rua central, 406 - fortaleza              PR  ...
# 8114     rua das flores, 230 - porto alegre              SP  ...
# 15125                                   NaN              SP  ...
# 17341         rua principal, 627 - brasilia              SP  ...
# 12362  rua das flores, 618 - rio de janeiro              RJ  ...
# 30199           rua central, 386 - curitiba              SP  ...
# 3080            rua da paz, 797 - fortaleza              PR  ...
# 23067           rua central, 598 - salvador              SP  ...
# 37197          rua das flores, 162 - manaus              RJ  ...
# 52280         rua principal, 747 - campinas              GO  ...
# 12785            rua central, 914 - goiania              AM  ...
# 41725    rua das flores, 683 - porto alegre              CE  ...
# 37758         rua principal, 293 - salvador              sp  ...
# 33618        rua das flores, 994 - salvador              PR  ...
# 25501                                   NaN              CE  ...
# 38600            rua da paz, 184 - salvador              PE  ...
# 52023       rua das flores, 394 - guarulhos              sp  ...
# 30686      rua da paz, 940 - belo horizonte              PA  ...
# 28982          rua principal, 29 - salvador              PE  ...
# 18229          rua central, 950 - fortaleza              SP  ...
# 3918          rua principal, 840 - brasilia              MG  ...
# 29245       rua das flores, 414 - fortaleza              SP  ...
# 15088      rua da paz, 285 - belo horizonte              CE  ...
# 10407       rua das flores, 847 - fortaleza  RIO DE JANEIRO  ...
# 42297           rua principal, 841 - manaus              sp  ...
# 8197               rua central, 632 - belem              AM  ...
# 34181     rua central, 107 - belo horizonte              SP  ...
# 37740       rua das flores, 102 - sao paulo              SP  ...
# 26798          rua central, 505 - fortaleza              SP  ...
# 29147                                   NaN              RJ  ...
# 47174  rua das flores, 929 - rio de janeiro              MG  ...
# 44909        rua principal, 898 - sao paulo              SP  ...
# 32131        rua das flores, 739 - campinas              PA  ...
# 26999            rua da paz, 691 - salvador              MG  ...
# 17009              rua da paz, 931 - manaus              PR  ...
# 6702      rua central, 924 - belo horizonte              SP  ...
# 17212           rua principal, 986 - manaus              AM  ...
# 25799      rua da paz, 842 - belo horizonte              GO  ...
# 34688        rua principal, 900 - sao paulo              RS  ...
# 46515     rua central, 410 - rio de janeiro              SP  ...
# 47035         rua principal, 240 - salvador              SP  ...
# 6566                rua central, 73 - belem              PE  ...
# 3624               rua da paz, 445 - recife              PE  ...
# 32012             rua central, 198 - manaus              DF  ...
# 12326           rua da paz, 994 - fortaleza              SP  ...
# 15100           rua principal, 461 - manaus              RJ  ...
# 18122         rua principal, 999 - campinas             N/I  ...
# 9903                                    NaN              PE  ...
# 51427         rua das flores, 646 - goiania              PA  ...
# 11713       rua das flores, 403 - guarulhos              RS  ...
# 6075        rua central, 245 - porto alegre              SP  ...
# 39402        rua das flores, 102 - campinas             N/I  ...
# 37934      rua da paz, 591 - belo horizonte              SP  ...
# 27287     rua central, 943 - rio de janeiro              CE  ...
# 37918      rua da paz, 860 - belo horizonte              AM  ...
# 20933       rua central, 545 - porto alegre              RS  ...
# 49568          rua das flores, 457 - manaus              DF  ...
#
#       status_da_conta score_de_credito  produto_favorito  \
# 40215       bloqueado              483        smartwatch
# 961           inativo              601    fone de ouvido
# 291             ativo              370           teclado
# 3671        bloqueado              737           teclado
# 8114        bloqueado              841          notebook
# 15125           ativo              737           teclado
# 17341         inativo              302          notebook
# 12362       bloqueado       850 pontos            camera
# 30199       bloqueado              694            tablet
# 3080            ativo              327               NaN
# 23067       bloqueado              440    fone de ouvido
# 37197             sim              315           monitor
# 52280           ativa              514        smartwatch
# 12785           ativo              356           monitor
# 41725        suspenso              466               NaN
# 37758         inativo              534               NaN
# 33618       bloqueado             Alto                tv
# 25501        suspenso            Baixo            camera
# 38600           ativo              786            tablet
# 52023           ativo              687            camera
# 30686               1             Alto           monitor
# 28982           ativo              896               NaN
# 18229       bloqueado              871           teclado
# 3918          inativo              803          notebook
# 29245               1              475           teclado
# 15088           ativo              809               NaN
# 10407           ativo              454           teclado
# 42297        suspenso              787               NaN
# 8197            ativo        Excelente           teclado
# 34181       bloqueado              779            tablet
# 37740         inativo              434           monitor
# 26798         inativo              NaN                tv
# 29147       bloqueado              374               NaN
# 47174       bloqueado              663    fone de ouvido
# 44909         inativo              851        smartphone
# 32131        suspenso              807            camera
# 26999        suspenso              795               NaN
# 17009           ativo              NaN            tablet
# 6702        bloqueado              539                tv
# 17212       bloqueado              702           teclado
# 25799           ativo              832            camera
# 34688           ativo              402        smartphone
# 46515         inativo              898             mouse
# 47035               a              NaN             mouse
# 6566        bloqueado        Excelente        smartwatch
# 3624          inativo             Alto        smartphone
# 32012           ativo              455            camera
# 12326       bloqueado              757           teclado
# 15100       bloqueado              738        smartwatch
# 18122         inativo              499            tablet
# 9903        bloqueado              862            tablet
# 51427         inativo              405                tv
# 11713        suspenso              875             mouse
# 6075         suspenso              NaN          notebook
# 39402        suspenso              666  tablet - produto
# 37934         inativo              373        smartphone
# 27287         inativo              493            camera
# 37918       bloqueado              329           teclado
# 20933           ativo              680                tv
# 49568           ativo              867            tablet
#
#       data_da_ultima_compra valor_total_gasto categoria_cliente unnamed_16  \
# 40215            13/07/2024           3128.68          diamante        NaN
# 961              09-08-2024            9495.7              ouro        NaN
# 291              20/04/2024            4146.6           platina        NaN
# 3671             2024-12-06           8469.41              ouro        NaN
# 8114             2024-08-07           3778.72             prata        NaN
# 15125            02/03/2024           6956.07             prata        NaN
# 17341            13/04/2024            5465.3             prata        NaN
# 12362            06-08-2024           4333.67           platina        NaN
# 30199            02/08/2024           9311.37            bronze        NaN
# 3080             2024-01-02           8754.98              ouro        NaN
# 23067            04/10/2024           1140.21           platina        NaN
# 37197            03-11-2024           4087.22           platina        NaN
# 52280            2024-09-16           2717.42          diamante        NaN
# 12785            22/01/2024           4116.05             prata        NaN
# 41725            26/01/2024               NaN          diamante        NaN
# 37758        Há muito tempo              Zero            bronze        NaN
# 33618            12-27-2024           3650.39           platina        NaN
# 25501            2024-06-23           1841.43          diamante        NaN
# 38600            11/01/2024            686.26           platina        NaN
# 52023            08-24-2024           9706.18             prata        NaN
# 30686            07-03-2024               NaN              ouro        NaN
# 28982            04-27-2024            353.04            bronze        NaN
# 18229            14/04/2024           7328.13              ouro        NaN
# 3918             26/05/2024           2822.31             prata        NaN
# 29245            12-16-2024           4223.53              ouro        NaN
# 15088            06-02-2024           3151.81           platina        NaN
# 10407            21/06/2024           8910.13          diamante        NaN
# 42297            27/02/2024           8346.99           premium        NaN
# 8197             10-23-2024           7302.58            bronze        NaN
# 34181            10-07-2024             207.3            bronze        NaN
# 37740            05/03/2024            2985.7              ouro        NaN
# 26798            02-13-2024               NaN             prata        NaN
# 29147            07-18-2024           2035.87              ouro        NaN
# 47174            01-26-2024           8822.78            bronze        NaN
# 44909            2024-12-19           4477.28          diamante        NaN
# 32131            04-09-2024           6518.18            bronze        NaN
# 26999            2024-06-26           4636.56          diamante        NaN
# 17009         Nunca comprou       R$ 1.250,50            bronze        NaN
# 6702             12-04-2024           6322.39             prata        NaN
# 17212            11-07-2024           6232.97          diamante        NaN
# 25799        Há muito tempo             Baixo             prata        NaN
# 34688            2024-08-28        Muito alto           platina        NaN
# 46515            2024-09-26           5052.45            bronze        NaN
# 47035            04/09/2024            783.91             prata        NaN
# 6566             2024/01/15           8811.23           platina        NaN
# 3624             26/03/2024           1993.77              ouro        NaN
# 32012         Nunca comprou            5236.9           platina        NaN
# 12326            2024-05-22           6144.92             prata        NaN
# 15100         Nunca comprou               NaN              ouro        NaN
# 18122                   NaN           3977.87           platina        NaN
# 9903             01-27-2024           2806.17          diamante        NaN
# 51427            2024-12-30           5448.74           platina        NaN
# 11713        Há muito tempo           2814.87             prata        NaN
# 6075                    NaN               NaN          diamante        NaN
# 39402            08-02-2024           2789.58              ouro        NaN
# 37934                   NaN            1046.5          diamante        NaN
# 27287            11-03-2024           7985.04              ouro        NaN
# 37918            05-18-2024            7165.2               NaN        NaN
# 20933        Há muito tempo           2782.36           platina        NaN
# 49568            2024-06-16           2484.13            bronze        NaN
#
#              obs_comentarios    ativo regional_zona
# 40215        Sem observações        n        centro
# 961          Sem observações        s           NaN
# 291                      NaN     true         leste
# 3671                     NaN        s         norte
# 8114                     NaN        n           sul
# 15125                    NaN        s           NaN
# 17341          Bom pagador          s           sul
# 12362                    NaN        s           NaN
# 30199                    NaN        n           NaN
# 3080   Observação importante        s         oeste
# 23067                    NaN    false           sul
# 37197        Sem observações        n         oeste
# 52280     Registro duplicado        s           sul
# 12785        Sem observações        n           sul
# 41725                    NaN        n        centro
# 37758                    NaN        n         oeste
# 33618       CLIENTE EXIGENTE        n         norte
# 25501                    NaN        n         leste
# 38600   Cliente preferencial        s  centro-oeste
# 52023                    NaN        s         norte
# 30686        Sem observações        n  centro-oeste
# 28982                    NaN        s        centro
# 18229                    NaN     true         oeste
# 3918                     NaN        n         norte
# 29245                    NaN        n           sul
# 15088                    NaN        s           sul
# 10407                    NaN    false         leste
# 42297                    NaN        s         norte
# 8197                     NaN        n           sul
# 34181                    NaN        n         leste
# 37740                    NaN  inativo           sul
# 26798                    NaN        n         oeste
# 29147                    NaN        n           sul
# 47174                    NaN        n         norte
# 44909                    NaN        s           sul
# 32131   Cliente preferencial        s        centro
# 26999                    NaN  inativo         norte
# 17009   Cliente preferencial        n        centro
# 6702              cliente!!!      nao           sul
# 17212                    NaN        n         leste
# 25799  Observação importante      NaN           sul
# 34688        Sem observações      NaN           sul
# 46515                    NaN        s           sul
# 47035                    NaN        s         leste
# 6566                     NaN        s         norte
# 3624                     NaN        n  centro-oeste
# 32012                    NaN        n  centro-oeste
# 12326                    NaN        s         leste
# 15100                    NaN        n           sul
# 18122                    NaN        n           sul
# 9903                     NaN        s           sul
# 51427     Registro duplicado        s  centro-oeste
# 11713                    NaN        s         norte
# 6075                     NaN        n           sul
# 39402       CLIENTE EXIGENTE        0        centro
# 37934                    NaN        n         oeste
# 27287                    NaN        n         norte
# 37918                    NaN        n         oeste
# 20933                    NaN        s         norte
# 49568                    NaN        s  centro-oeste
#
# [60 rows x 21 columns]

# %%
df1.dtypes
# Out:
# id_cliente                 int64
# nome_completo             object
# nome_limpo                object
# email                     object
# idade                    float64
# data_de_nascimento        object
# telefone_celular          object
# cep                       object
# endereco                  object
# estado_uf                 object
# salario                   object
# status_da_conta           object
# score_de_credito          object
# produto_favorito          object
# data_da_ultima_compra     object
# valor_total_gasto         object
# categoria_cliente         object
# unnamed_16               float64
# obs_comentarios           object
# ativo                     object
# regional_zona             object
# dtype: object

# %% [markdown]
# ## Limpando os Dados

# %% [markdown]
# - remover duplicatas
# - tratar valores faltantes
# - corrigir inconsistências
# - tratar outliers
# - validar regras de negócio

# %% [markdown]
# ### Tratamento de Valores Ausentes

# %% [markdown]
# #### Deletando Colunas Vazias

# %%
df1 = df1.drop(columns=["unnamed_16"])

# %%
df1.head()
# Out:
#    id_cliente   nome_completo      nome_limpo                      email  \
# 0           1       Ana Silva       ana silva        ana.silva@yahoo.com
# 1           2     Carla Souza     carla souza                        NaN
# 2           3       Ana Costa       ana costa      ana.costa@hotmail.com
# 3           4  Mariana Santos  mariana santos  mariana.santos@bol.com.br
# 4           5     Maria Silva     maria silva    maria.silva@hotmail.com
#
#    idade data_de_nascimento telefone_celular        cep  \
# 0   56.0       Janeiro 1992  (85) 16400-0408   04397312
# 1   69.0         10/18/1950    31 87481-2231     123456
# 2   46.0                NaN  (11) 93064-3172  81093-112
# 3   32.0         06/08/1976  (11) 42963-8044   80681606
# 4   60.0         03/19/2001    11 60767-0256  34867-654
#
#                          endereco estado_uf               salario  \
# 0                             NaN        CE  Salário confidencial
# 1  rua principal, 935 - guarulhos        PA         Não informado
# 2    rua central, 633 - fortaleza        RJ                 12030
# 3   rua principal, 630 - brasilia        RS                 12038
# 4     rua da paz, 673 - fortaleza        BA                 14659
#
#   status_da_conta score_de_credito produto_favorito data_da_ultima_compra  \
# 0        suspenso              852          monitor            30/09/2024
# 1           ativo              517          monitor            2024-09-13
# 2               a              428          teclado            03-13-2024
# 3         inativo              662         notebook            04-06-2024
# 4       bloqueado              375           camera            01-27-2024
#
#   valor_total_gasto categoria_cliente obs_comentarios  ativo regional_zona
# 0           4495.03              ouro             NaN  ativo         norte
# 1           6751.27          diamante             NaN      s  centro-oeste
# 2           6900.93              ouro             NaN      n  centro-oeste
# 3           3743.36           platina             NaN      n        centro
# 4            9077.3              ouro             NaN      n        centro

# %% [markdown]
# #### Valores Ausentes

# %%
df1.isna().sum()
# Out:
# id_cliente                   0
# nome_completo                0
# nome_limpo                   0
# email                     9732
# idade                     6386
# data_de_nascimento        2575
# telefone_celular          2097
# cep                       2163
# endereco                  5220
# estado_uf                 1402
# salario                   2073
# status_da_conta           1046
# score_de_credito          3039
# produto_favorito          6230
# data_da_ultima_compra     3346
# valor_total_gasto         2105
# categoria_cliente         1162
# obs_comentarios          40034
# ativo                     1096
# regional_zona             2677
# dtype: int64

# %%
len(df1)
# Out:
# 52500

# %%
# Deletando a coluna de observações

df1 = df1.drop(columns=["obs_comentarios"])

# %%
df1.head()
# Out:
#    id_cliente   nome_completo      nome_limpo                      email  \
# 0           1       Ana Silva       ana silva        ana.silva@yahoo.com
# 1           2     Carla Souza     carla souza                        NaN
# 2           3       Ana Costa       ana costa      ana.costa@hotmail.com
# 3           4  Mariana Santos  mariana santos  mariana.santos@bol.com.br
# 4           5     Maria Silva     maria silva    maria.silva@hotmail.com
#
#    idade data_de_nascimento telefone_celular        cep  \
# 0   56.0       Janeiro 1992  (85) 16400-0408   04397312
# 1   69.0         10/18/1950    31 87481-2231     123456
# 2   46.0                NaN  (11) 93064-3172  81093-112
# 3   32.0         06/08/1976  (11) 42963-8044   80681606
# 4   60.0         03/19/2001    11 60767-0256  34867-654
#
#                          endereco estado_uf               salario  \
# 0                             NaN        CE  Salário confidencial
# 1  rua principal, 935 - guarulhos        PA         Não informado
# 2    rua central, 633 - fortaleza        RJ                 12030
# 3   rua principal, 630 - brasilia        RS                 12038
# 4     rua da paz, 673 - fortaleza        BA                 14659
#
#   status_da_conta score_de_credito produto_favorito data_da_ultima_compra  \
# 0        suspenso              852          monitor            30/09/2024
# 1           ativo              517          monitor            2024-09-13
# 2               a              428          teclado            03-13-2024
# 3         inativo              662         notebook            04-06-2024
# 4       bloqueado              375           camera            01-27-2024
#
#   valor_total_gasto categoria_cliente  ativo regional_zona
# 0           4495.03              ouro  ativo         norte
# 1           6751.27          diamante      s  centro-oeste
# 2           6900.93              ouro      n  centro-oeste
# 3           3743.36           platina      n        centro
# 4            9077.3              ouro      n        centro

# %% [markdown]
# #### Duplicatas

# %%
df1.duplicated().sum()
# Out:
# np.int64(2500)

# %%
df1.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 52495     True
# 52496     True
# 52497     True
# 52498     True
# 52499     True
# Length: 52500, dtype: bool

# %%
df1[df1.duplicated()]
# Out:
#        id_cliente     nome_completo        nome_limpo  \
# 50000       31362     Maria   Gomes       maria gomes
# 50001       16722     Rafael Santos     rafael santos
# 50002       36789  Claudia Oliveira  claudia oliveira
# 50003       22819       Pedro Souza       pedro souza
# 50004       24795       Maria Souza       maria souza
# ...           ...               ...               ...
# 52495       26846    Paulo Ferreira    paulo ferreira
# 52496       45552    Patricia Silva    patricia silva
# 52497       25412        João Alves        joao alves
# 52498       44726       Lucia Gomes       lucia gomes
# 52499       30012  Carlos Rodrigues  carlos rodrigues
#
#                               email  idade data_de_nascimento  \
# 50000      maria...gomes@uol.com.br   24.0         10/24/1999
# 50001      rafael.santos@bol.com.br   76.0         11/06/1985
# 50002  claudia.oliveira@hotmail.com   42.0         01/22/1956
# 50003        pedro.souza@bol.com.br   35.0         12/08/1960
# 50004         maria.souza@yahoo.com   70.0         09/24/1958
# ...                             ...    ...                ...
# 52495    paulo.ferreira@outlook.com   38.0         09/21/1996
# 52496     patricia.silva@uol.com.br   53.0         11/09/1968
# 52497         joão.alves@uol.com.br   18.0         06/09/1968
# 52498         lucia.gomes@gmail.com   75.0         15/02/1990
# 52499  carlos.rodrigues@outlook.com   35.0         01/16/1970
#
#       telefone_celular        cep                              endereco  \
# 50000  (21) 61369-1296   28607746  rua das flores, 401 - belo horizonte
# 50001    11 62613-2573   85267384     rua central, 546 - belo horizonte
# 50002    11 49487-5313   88836534       rua das flores, 172 - sao paulo
# 50003      11999999999  87846-239               rua central, 80 - belem
# 50004      85642656137  04704-402       rua central, 557 - porto alegre
# ...                ...        ...                                   ...
# 52495  (11) 02698-1177   55227309  rua das flores, 941 - rio de janeiro
# 52496  (11) 99999-9999  05529-465     rua central, 860 - rio de janeiro
# 52497              123   60427184             rua da paz, 51 - brasilia
# 52498      11587515945   71609249          rua da paz, 2 - porto alegre
# 52499    11 58549-1317  02218-308          rua das flores, 372 - manaus
#
#       estado_uf   salario status_da_conta score_de_credito produto_favorito  \
# 50000        RJ      5506           ativo              849            mouse
# 50001        RJ      6995         inativo              NaN          teclado
# 50002       NaN      8966        suspenso              429       smartphone
# 50003        BA     14658        suspenso              NaN          monitor
# 50004        MG     11155       bloqueado              561          monitor
# ...         ...       ...             ...              ...              ...
# 52495        SP     14486        suspenso              550               tv
# 52496        SP  3,500.50         inativo              836         notebook
# 52497        PE      6930       bloqueado              866          teclado
# 52498        SP      9779           ativo            Baixo           camera
# 52499        RS      8644       bloqueado              381            mouse
#
#       data_da_ultima_compra valor_total_gasto categoria_cliente    ativo  \
# 50000         Nunca comprou           3640.34           platina  inativo
# 50001            03/10/2024           3231.28             prata        n
# 50002            2024-12-07           2322.92             prata        n
# 50003                   NaN            743.35             prata        n
# 50004            05/12/2024           3910.55           platina      NaN
# ...                     ...               ...               ...      ...
# 52495            13/07/2024           2090.78            bronze        n
# 52496            2024/01/15            R$2500            bronze        s
# 52497            10-28-2024            718.06            bronze        n
# 52498            12-30-2024           1218.89              ouro        s
# 52499            09/09/2024           3468.76           platina        n
#
#       regional_zona
# 50000         norte
# 50001  centro-oeste
# 50002         norte
# 50003           sul
# 50004         norte
# ...             ...
# 52495           sul
# 52496        centro
# 52497         norte
# 52498         norte
# 52499           sul
#
# [2500 rows x 19 columns]

# %%
df1 = df1.drop_duplicates()

# %%
# Conferindo se as duplicatas foram removidas
df1[df1.duplicated()]
# Out:
# Empty DataFrame
# Columns: [id_cliente, nome_completo, nome_limpo, email, idade, data_de_nascimento, telefone_celular, cep, endereco, estado_uf, salario, status_da_conta, score_de_credito, produto_favorito, data_da_ultima_compra, valor_total_gasto, categoria_cliente, ativo, regional_zona]
# Index: []

# %%
df1.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Enriquecer/Transformar os Dados

# %% [markdown]
# - criar novas colunas
# - fazer joins
# - preparar para modelagem

# %% [markdown]
# ### Coluna de Nomes Limpos Para Processamento de Dados
