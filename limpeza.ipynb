# %% [markdown]
# # Pipeline de Limpeza de Dados

# %% [markdown]
# ## Importandos as Bibliotecas e os Dados

# %%
# Bibliotecas

import pandas as pd
import unicodedata
import re
import numpy as np

# %%
# Dados

df = pd.read_csv("dados.csv")
df1 = df.copy()

# %% [markdown]
# ## Vizualizando o Dataframe

# %%
df1.head()
# Out:
#      ID Cliente    NOME COMPLETO!             E-mail@Principal  idade   \
# 0               1       Ana Silva          ana.silva@yahoo.com      56
# 1               2     Carla Souza                          NaN      69
# 2               3       Ana Costa        ana.costa@hotmail.com      46
# 3               4  Mariana Santos    mariana.santos@bol.com.br      32
# 4               5     MARIA silva    maria.silva@hotmail.com        60
#
#   Data de Nascimento# Telefone/Celular CEP (Código)  \
# 0        Janeiro 1992  (85) 16400-0408     04397312
# 1          10/18/1950    31 87481-2231       123456
# 2                 NaN  (11) 93064-3172    81093-112
# 3          06/08/1976  (11) 42963-8044     80681606
# 4          03/19/2001    11 60767-0256    34867-654
#
#                 Endereço & Cidade Estado-UF          Salário (R$)  \
# 0                             NaN        CE  Salário confidencial
# 1  Rua Principal, 935 - Guarulhos        PA         Não informado
# 2    Rua Central, 633 - Fortaleza        RJ                 12030
# 3   Rua Principal, 630 - Brasília        RS                 12038
# 4     Rua da Paz, 673 - Fortaleza        BA                 14659
#
#   Status_da_Conta Score de Crédito% Produto Favorito* Data da Última Compra  \
# 0        Suspenso               852           Monitor            30/09/2024
# 1           Ativo               517           Monitor            2024-09-13
# 2               A               428           TECLADO            03-13-2024
# 3         Inativo               662          Notebook            04-06-2024
# 4       Bloqueado               375            CAMERA            01-27-2024
#
#   Valor Total Gasto Categoria-Cliente  Unnamed: 16 Obs: Comentários  \
# 0           4495.03              Ouro          NaN              NaN
# 1           6751.27          Diamante          NaN              NaN
# 2           6900.93              Ouro          NaN              NaN
# 3           3743.36           Platina          NaN              NaN
# 4            9077.3              Ouro          NaN              NaN
#
#   Ativo? (S/N) Regional/Zona
# 0        Ativo         norte
# 1            S  centro-oeste
# 2            N  centro-oeste
# 3            N        Centro
# 4            N        Centro

# %%
df1.dtypes
# Out:
#   ID Cliente               int64
# NOME COMPLETO!            object
# E-mail@Principal          object
#  idade                    object
# Data de Nascimento#       object
# Telefone/Celular          object
# CEP (Código)              object
# Endereço & Cidade         object
# Estado-UF                 object
# Salário (R$)              object
# Status_da_Conta           object
# Score de Crédito%         object
# Produto Favorito*         object
# Data da Última Compra     object
# Valor Total Gasto         object
# Categoria-Cliente         object
# Unnamed: 16              float64
# Obs: Comentários          object
# Ativo? (S/N)              object
# Regional/Zona             object
# dtype: object

# %%
df1.shape
# Out:
# (52500, 20)

# %%
df1.describe
# Out:
# <bound method NDFrame.describe of          ID Cliente      NOME COMPLETO!                E-mail@Principal  \
# 0                   1         Ana Silva             ana.silva@yahoo.com
# 1                   2       Carla Souza                             NaN
# 2                   3         Ana Costa           ana.costa@hotmail.com
# 3                   4    Mariana Santos       mariana.santos@bol.com.br
# 4                   5       MARIA silva       maria.silva@hotmail.com
# ...               ...               ...                             ...
# 52495           26846    PAULO ferreira    paulo.ferreira@outlook.com
# 52496           45552    Patricia Silva     patricia.silva@uol.com.br
# 52497           25412        João Alves           joão.alves@uol.com.br
# 52498           44726       Lucia Gomes           lucia.gomes@gmail.com
# 52499           30012  Carlos Rodrigues    carlos.rodrigues@outlook.com
#
#        idade  Data de Nascimento# Telefone/Celular CEP (Código)  \
# 0          56        Janeiro 1992  (85) 16400-0408     04397312
# 1          69          10/18/1950    31 87481-2231       123456
# 2          46                 NaN  (11) 93064-3172    81093-112
# 3          32          06/08/1976  (11) 42963-8044     80681606
# 4          60          03/19/2001    11 60767-0256    34867-654
# ...       ...                 ...              ...          ...
# 52495      38          09/21/1996  (11) 02698-1177     55227309
# 52496      53          11/09/1968  (11) 99999-9999    05529-465
# 52497      18          06/09/1968              123     60427184
# 52498      75          15/02/1990      11587515945     71609249
# 52499      35          01/16/1970    11 58549-1317    02218-308
#
#                           Endereço & Cidade Estado-UF          Salário (R$)  \
# 0                                       NaN        CE  Salário confidencial
# 1            Rua Principal, 935 - Guarulhos        PA         Não informado
# 2              Rua Central, 633 - Fortaleza        RJ                 12030
# 3             Rua Principal, 630 - Brasília        RS                 12038
# 4               Rua da Paz, 673 - Fortaleza        BA                 14659
# ...                                     ...       ...                   ...
# 52495  Rua das Flores, 941 - Rio de Janeiro        SP                 14486
# 52496     Rua Central, 860 - Rio de Janeiro        SP              3,500.50
# 52497             Rua da Paz, 51 - Brasília        PE                  6930
# 52498          Rua da Paz, 2 - Porto Alegre        SP                  9779
# 52499          Rua das Flores, 372 - Manaus        RS                  8644
#
#       Status_da_Conta Score de Crédito% Produto Favorito*  \
# 0            Suspenso               852           Monitor
# 1               Ativo               517           Monitor
# 2                   A               428           TECLADO
# 3             Inativo               662          Notebook
# 4           Bloqueado               375            CAMERA
# ...               ...               ...               ...
# 52495        Suspenso               550                TV
# 52496         Inativo               836          Notebook
# 52497       Bloqueado               866           Teclado
# 52498           Ativo             Baixo            Camera
# 52499       Bloqueado               381             Mouse
#
#       Data da Última Compra Valor Total Gasto Categoria-Cliente  Unnamed: 16  \
# 0                30/09/2024           4495.03              Ouro          NaN
# 1                2024-09-13           6751.27          Diamante          NaN
# 2                03-13-2024           6900.93              Ouro          NaN
# 3                04-06-2024           3743.36           Platina          NaN
# 4                01-27-2024            9077.3              Ouro          NaN
# ...                     ...               ...               ...          ...
# 52495            13/07/2024           2090.78            Bronze          NaN
# 52496            2024/01/15            R$2500            Bronze          NaN
# 52497            10-28-2024            718.06            Bronze          NaN
# 52498            12-30-2024           1218.89              Ouro          NaN
# 52499            09/09/2024           3468.76           Platina          NaN
#
#          Obs: Comentários Ativo? (S/N) Regional/Zona
# 0                     NaN        Ativo         norte
# 1                     NaN            S  centro-oeste
# 2                     NaN            N  centro-oeste
# 3                     NaN            N        Centro
# 4                     NaN            N        Centro
# ...                   ...          ...           ...
# 52495    CLIENTE EXIGENTE            N           Sul
# 52496  Registro duplicado            S        Centro
# 52497  Registro duplicado            N         norte
# 52498  Registro duplicado            S         Norte
# 52499                 NaN            N           SUL
#
# [52500 rows x 20 columns]>

# %%
df1.isnull().sum()
# Out:
#   ID Cliente                 0
# NOME COMPLETO!               0
# E-mail@Principal          7888
#  idade                    2164
# Data de Nascimento#       2575
# Telefone/Celular          2097
# CEP (Código)              2163
# Endereço & Cidade         5220
# Estado-UF                 1402
# Salário (R$)              2073
# Status_da_Conta           1046
# Score de Crédito%         3039
# Produto Favorito*         6230
# Data da Última Compra     3346
# Valor Total Gasto         2105
# Categoria-Cliente         1162
# Unnamed: 16              52500
# Obs: Comentários         40034
# Ativo? (S/N)              1096
# Regional/Zona             2677
# dtype: int64

# %% [markdown]
# ## Padronizando os Dados

# %% [markdown]
# - remover espaços
# - normalizar acentos
# - transformar para minúsculas
# - padronizar datas
# - converter tipos
# - normalizar categorias

# %% [markdown]
# ### Padronização dos Nomes das Colunas

# %%
# função de padronização das colunas
def padronizar_colunas(colunas):
    novas_colunas = []
    for col in colunas:
        col = unicodedata.normalize('NFKD', col).encode('ascii', 'ignore').decode('utf-8')
        col = col.lower()
        col = re.sub(r'[^a-z0-9_]', '_', col)
        col = re.sub(r'_+', '_', col)
        col = col.strip('_')
        novas_colunas.append(col)
    return novas_colunas

df1.columns = padronizar_colunas(df1.columns)

# %%
df1.head()
# Out:
#    id_cliente   nome_completo             e_mail_principal idade  \
# 0           1       Ana Silva          ana.silva@yahoo.com    56
# 1           2     Carla Souza                          NaN    69
# 2           3       Ana Costa        ana.costa@hotmail.com    46
# 3           4  Mariana Santos    mariana.santos@bol.com.br    32
# 4           5     MARIA silva    maria.silva@hotmail.com      60
#
#   data_de_nascimento telefone_celular cep_codigo  \
# 0       Janeiro 1992  (85) 16400-0408   04397312
# 1         10/18/1950    31 87481-2231     123456
# 2                NaN  (11) 93064-3172  81093-112
# 3         06/08/1976  (11) 42963-8044   80681606
# 4         03/19/2001    11 60767-0256  34867-654
#
#                   endereco_cidade estado_uf             salario_r  \
# 0                             NaN        CE  Salário confidencial
# 1  Rua Principal, 935 - Guarulhos        PA         Não informado
# 2    Rua Central, 633 - Fortaleza        RJ                 12030
# 3   Rua Principal, 630 - Brasília        RS                 12038
# 4     Rua da Paz, 673 - Fortaleza        BA                 14659
#
#   status_da_conta score_de_credito produto_favorito data_da_ultima_compra  \
# 0        Suspenso              852          Monitor            30/09/2024
# 1           Ativo              517          Monitor            2024-09-13
# 2               A              428          TECLADO            03-13-2024
# 3         Inativo              662         Notebook            04-06-2024
# 4       Bloqueado              375           CAMERA            01-27-2024
#
#   valor_total_gasto categoria_cliente  unnamed_16 obs_comentarios ativo_s_n  \
# 0           4495.03              Ouro         NaN             NaN     Ativo
# 1           6751.27          Diamante         NaN             NaN         S
# 2           6900.93              Ouro         NaN             NaN         N
# 3           3743.36           Platina         NaN             NaN         N
# 4            9077.3              Ouro         NaN             NaN         N
#
#   regional_zona
# 0         norte
# 1  centro-oeste
# 2  centro-oeste
# 3        Centro
# 4        Centro

# %%
# Renomeando colunas específicas

df1 = df1.rename(columns={
    "e_mail_principal": "email",
    "cep_codigo": "cep",
    "endereco_cidade": "endereco",
    "salario_r": "salario",
    "ativo_s_n": "ativo"
})

# %%
df1.head()
# Out:
#    id_cliente   nome_completo                        email idade  \
# 0           1       Ana Silva          ana.silva@yahoo.com    56
# 1           2     Carla Souza                          NaN    69
# 2           3       Ana Costa        ana.costa@hotmail.com    46
# 3           4  Mariana Santos    mariana.santos@bol.com.br    32
# 4           5     MARIA silva    maria.silva@hotmail.com      60
#
#   data_de_nascimento telefone_celular        cep  \
# 0       Janeiro 1992  (85) 16400-0408   04397312
# 1         10/18/1950    31 87481-2231     123456
# 2                NaN  (11) 93064-3172  81093-112
# 3         06/08/1976  (11) 42963-8044   80681606
# 4         03/19/2001    11 60767-0256  34867-654
#
#                          endereco estado_uf               salario  \
# 0                             NaN        CE  Salário confidencial
# 1  Rua Principal, 935 - Guarulhos        PA         Não informado
# 2    Rua Central, 633 - Fortaleza        RJ                 12030
# 3   Rua Principal, 630 - Brasília        RS                 12038
# 4     Rua da Paz, 673 - Fortaleza        BA                 14659
#
#   status_da_conta score_de_credito produto_favorito data_da_ultima_compra  \
# 0        Suspenso              852          Monitor            30/09/2024
# 1           Ativo              517          Monitor            2024-09-13
# 2               A              428          TECLADO            03-13-2024
# 3         Inativo              662         Notebook            04-06-2024
# 4       Bloqueado              375           CAMERA            01-27-2024
#
#   valor_total_gasto categoria_cliente  unnamed_16 obs_comentarios  ativo  \
# 0           4495.03              Ouro         NaN             NaN  Ativo
# 1           6751.27          Diamante         NaN             NaN      S
# 2           6900.93              Ouro         NaN             NaN      N
# 3           3743.36           Platina         NaN             NaN      N
# 4            9077.3              Ouro         NaN             NaN      N
#
#   regional_zona
# 0         norte
# 1  centro-oeste
# 2  centro-oeste
# 3        Centro
# 4        Centro

# %% [markdown]
# ### Padronização de Colunas Diversas

# %%
df1.head()
# Out:
#    id_cliente   nome_completo                        email idade  \
# 0           1       Ana Silva          ana.silva@yahoo.com    56
# 1           2     Carla Souza                          NaN    69
# 2           3       Ana Costa        ana.costa@hotmail.com    46
# 3           4  Mariana Santos    mariana.santos@bol.com.br    32
# 4           5     MARIA silva    maria.silva@hotmail.com      60
#
#   data_de_nascimento telefone_celular        cep  \
# 0       Janeiro 1992  (85) 16400-0408   04397312
# 1         10/18/1950    31 87481-2231     123456
# 2                NaN  (11) 93064-3172  81093-112
# 3         06/08/1976  (11) 42963-8044   80681606
# 4         03/19/2001    11 60767-0256  34867-654
#
#                          endereco estado_uf               salario  \
# 0                             NaN        CE  Salário confidencial
# 1  Rua Principal, 935 - Guarulhos        PA         Não informado
# 2    Rua Central, 633 - Fortaleza        RJ                 12030
# 3   Rua Principal, 630 - Brasília        RS                 12038
# 4     Rua da Paz, 673 - Fortaleza        BA                 14659
#
#   status_da_conta score_de_credito produto_favorito data_da_ultima_compra  \
# 0        Suspenso              852          Monitor            30/09/2024
# 1           Ativo              517          Monitor            2024-09-13
# 2               A              428          TECLADO            03-13-2024
# 3         Inativo              662         Notebook            04-06-2024
# 4       Bloqueado              375           CAMERA            01-27-2024
#
#   valor_total_gasto categoria_cliente  unnamed_16 obs_comentarios  ativo  \
# 0           4495.03              Ouro         NaN             NaN  Ativo
# 1           6751.27          Diamante         NaN             NaN      S
# 2           6900.93              Ouro         NaN             NaN      N
# 3           3743.36           Platina         NaN             NaN      N
# 4            9077.3              Ouro         NaN             NaN      N
#
#   regional_zona
# 0         norte
# 1  centro-oeste
# 2  centro-oeste
# 3        Centro
# 4        Centro

# %%
cols = ['endereco', 'status_da_conta', 'produto_favorito', 'categoria_cliente', 'ativo', 'regional_zona']

for col in cols:
    df1[col] = (
        df1[col]
        .str.normalize('NFKD')
        .str.encode('ascii', errors='ignore')
        .str.decode('utf-8')
        .str.lower()
        .str.strip()
        .str.replace(r'\s+', ' ', regex=True)
    )

# %%
df1.head()
# Out:
#    id_cliente   nome_completo                        email idade  \
# 0           1       Ana Silva          ana.silva@yahoo.com    56
# 1           2     Carla Souza                          NaN    69
# 2           3       Ana Costa        ana.costa@hotmail.com    46
# 3           4  Mariana Santos    mariana.santos@bol.com.br    32
# 4           5     MARIA silva    maria.silva@hotmail.com      60
#
#   data_de_nascimento telefone_celular        cep  \
# 0       Janeiro 1992  (85) 16400-0408   04397312
# 1         10/18/1950    31 87481-2231     123456
# 2                NaN  (11) 93064-3172  81093-112
# 3         06/08/1976  (11) 42963-8044   80681606
# 4         03/19/2001    11 60767-0256  34867-654
#
#                          endereco estado_uf               salario  \
# 0                             NaN        CE  Salário confidencial
# 1  rua principal, 935 - guarulhos        PA         Não informado
# 2    rua central, 633 - fortaleza        RJ                 12030
# 3   rua principal, 630 - brasilia        RS                 12038
# 4     rua da paz, 673 - fortaleza        BA                 14659
#
#   status_da_conta score_de_credito produto_favorito data_da_ultima_compra  \
# 0        suspenso              852          monitor            30/09/2024
# 1           ativo              517          monitor            2024-09-13
# 2               a              428          teclado            03-13-2024
# 3         inativo              662         notebook            04-06-2024
# 4       bloqueado              375           camera            01-27-2024
#
#   valor_total_gasto categoria_cliente  unnamed_16 obs_comentarios  ativo  \
# 0           4495.03              ouro         NaN             NaN  ativo
# 1           6751.27          diamante         NaN             NaN      s
# 2           6900.93              ouro         NaN             NaN      n
# 3           3743.36           platina         NaN             NaN      n
# 4            9077.3              ouro         NaN             NaN      n
#
#   regional_zona
# 0         norte
# 1  centro-oeste
# 2  centro-oeste
# 3        centro
# 4        centro

# %% [markdown]
# ### Padronização Específica por Coluna

# %% [markdown]
# #### Padronização da Coluna "nome_completo"

# %%
df1["nome_completo"].tail()
# Out:
# 52495      PAULO ferreira
# 52496      Patricia Silva
# 52497          João Alves
# 52498         Lucia Gomes
# 52499    Carlos Rodrigues
# Name: nome_completo, dtype: object

# %%
df1['nome_completo'] = df1['nome_completo'].str.title()

# %%
df1['nome_completo'] = df1['nome_completo'].str.replace(
    r'^(sr\.?|sra\.?|srta\.?|dr\.?|dra\.?|prof\.?|profa\.?)\s*',
    '',
    regex=True,
    flags=re.IGNORECASE
)

# %%
df1["nome_completo"].tail()
# Out:
# 52495      Paulo Ferreira
# 52496      Patricia Silva
# 52497          João Alves
# 52498         Lucia Gomes
# 52499    Carlos Rodrigues
# Name: nome_completo, dtype: object

# %%
# Criando a coluna "nome_limpo"

df1['nome_limpo'] = (
    df1['nome_completo']
    .str.normalize('NFKD')
    .str.encode('ascii', errors='ignore')
    .str.decode('utf-8')
    .str.lower()
    .str.strip()
    .str.replace(r'\s+', ' ', regex=True)
)

colunas = list(df1.columns)

# Alterando a posição da coluna nome_limpo

idx = colunas.index('nome_completo')
colunas.remove('nome_limpo')
colunas.insert(idx + 1, 'nome_limpo')
df1 = df1[colunas]

# %%
df1["nome_completo"].head()
# Out:
# 0         Ana Silva
# 1       Carla Souza
# 2         Ana Costa
# 3    Mariana Santos
# 4       Maria Silva
# Name: nome_completo, dtype: object

# %% [markdown]
# #### Padronização da Coluna "email"

# %% [markdown]
# **O que pode ser feito com segurança**
#
# - Remover espaços extras
# - Converter para minúsculas
# - Remover quebras de linha
# - Tratar casos óbvios de sujeira (“;”, vírgulas, espaços no meio)
# - Validar formato básico (opcional)
#
# **O que não deve ser feito**
#
# - Não remover pontos antes do @ (ex.: joao.silva@gmail.com ≠ joaosilva@gmail.com)
# - Não remover sinais como “+” (ex.: joao+teste@gmail.com é válido)
# - Não tentar “corrigir” domínios manualmente
# - Não aplicar normalização de acentos (e‑mail não deve ter acentos, mas se tiver, é melhor sinalizar do que alterar)

# %%
df1["email"].tail()
# Out:
# 52495      paulo.ferreira@outlook.com
# 52496       patricia.silva@uol.com.br
# 52497             joão.alves@uol.com.br
# 52498             lucia.gomes@gmail.com
# 52499      carlos.rodrigues@outlook.com
# Name: email, dtype: object

# %%
df1['email'] = (
    df1['email']
    .astype(str)
    .str.strip()
    .str.lower()
    .str.replace(r'\s+', '', regex=True)
    .str.replace(r'[;,]+', '', regex=True)
)

# %%
def limpar_e_validar_email(e):
    e = str(e).strip().lower()
    e = e.replace(" ", "")

    # Valores "nulos"
    if e in ["", "nao_informado", "não_informado", "nao informado", "none", "null"]:
        return np.nan

    # Sem arroba
    if '@' not in e:
        return np.nan

    usuario, dominio = e.split('@', 1)

    # Sem usuario antes do @
    if usuario == "":
        return np.nan

    # Dominio sem ponto
    if '.' not in dominio:
        return np.nan

    return e

# %%
df1['email'] = df1['email'].apply(limpar_e_validar_email).astype('string')

# %%
df1["email"].tail()
# Out:
# 52495      paulo.ferreira@outlook.com
# 52496       patricia.silva@uol.com.br
# 52497           joão.alves@uol.com.br
# 52498           lucia.gomes@gmail.com
# 52499    carlos.rodrigues@outlook.com
# Name: email, dtype: string

# %%
df1["email"].dtype
# Out:
# string[python]

# %% [markdown]
# #### Padronização da Coluna "idade"

# %%
df1["idade"].tail()
# Out:
# 52495    38
# 52496    53
# 52497    18
# 52498    75
# 52499    35
# Name: idade, dtype: object

# %%
df1["idade"].dtype
# Out:
# dtype('O')

# %%
df1["idade"].unique()
# Out:
# array(['56', '69', '46', '32', '60', '25', '78', 'Não informado', '38',
#        '75', '36', '40', '28', '41', '70', '53', '57', nan, '20', '39',
#        '19', '61', '47', '55', '-5', '77', '50', '29', '42', 'idoso',
#        '66', '44', '76', '150', '59', '45', '33', '79', '64', '68', '72',
#        '74', '54', '24', '26', '35', '21', '31', '67', '43', '37',
#        '25 anos', '52', '34', '23', '71', '51', '27', '48', '65', '62',
#        '58', '18', '22', '30', '49', 'menor de idade', '73', '63'],
#       dtype=object)

# %%
def limpar_idade(valor):
    if pd.isna(valor):
        return np.nan
    valor = str(valor).strip()
    if valor.lower() in ["", "nan", "não informado", "nao informado", "none", "null"]:
        return np.nan
    valor = re.sub(r'[^0-9]', '', valor)
    if valor == "":
        return np.nan
    idade = int(valor)
    if idade < 0 or idade > 100:
        return np.nan
    return idade

# %%
df1['idade'] = df1['idade'].apply(limpar_idade).astype('Int64')

# %%
df1["idade"].unique()
# Out:
# <IntegerArray>
# [  56,   69,   46,   32,   60,   25,   78, <NA>,   38,   75,   36,   40,   28,
#    41,   70,   53,   57,   20,   39,   19,   61,   47,   55,    5,   77,   50,
#    29,   42,   66,   44,   76,   59,   45,   33,   79,   64,   68,   72,   74,
#    54,   24,   26,   35,   21,   31,   67,   43,   37,   52,   34,   23,   71,
#    51,   27,   48,   65,   62,   58,   18,   22,   30,   49,   73,   63]
# Length: 64, dtype: Int64

# %%
df1["idade"].head()
# Out:
# 0    56
# 1    69
# 2    46
# 3    32
# 4    60
# Name: idade, dtype: Int64

# %%
df1["idade"].dtype
# Out:
# Int64Dtype()

# %% [markdown]
# #### Padronização das Colunas "data_de_nascimento" e "data_da_ultima_compra"

# %%
df1["data_de_nascimento"].head()
# Out:
# 0    Janeiro 1992
# 1      10/18/1950
# 2             NaN
# 3      06/08/1976
# 4      03/19/2001
# Name: data_de_nascimento, dtype: object

# %%
df1["data_da_ultima_compra"].head()
# Out:
# 0    30/09/2024
# 1    2024-09-13
# 2    03-13-2024
# 3    04-06-2024
# 4    01-27-2024
# Name: data_da_ultima_compra, dtype: object

# %%
def limpar_data(col, validar_intervalo=True, ano_min=1900, ano_max=2026):
    # Converte para formato de data (datetime)
    col = pd.to_datetime(col, errors='coerce')
    
    # Validação de intervalo ()
    if validar_intervalo:
        if ano_min is not None:
            col = col.mask(col.dt.year < ano_min, pd.NaT)
        if ano_max is not None:
            col = col.mask(col.dt.year > ano_max, pd.NaT)
    
    return col

# %%
df1['data_de_nascimento'] = limpar_data(df1['data_de_nascimento'], validar_intervalo=True, ano_min=1900, ano_max=2026)
df1['data_da_ultima_compra'] = limpar_data(df1['data_da_ultima_compra'])
# Out:
# C:\Users\letic\AppData\Local\Temp\ipykernel_22612\3487823548.py:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   col = pd.to_datetime(col, errors='coerce')
# C:\Users\letic\AppData\Local\Temp\ipykernel_22612\3487823548.py:3: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   col = pd.to_datetime(col, errors='coerce')

# %%
df1["data_de_nascimento"].head()
# Out:
# 0          NaT
# 1   1950-10-18
# 2          NaT
# 3   1976-06-08
# 4   2001-03-19
# Name: data_de_nascimento, dtype: datetime64[ns]

# %%
df1["data_da_ultima_compra"].head()
# Out:
# 0   2024-09-30
# 1          NaT
# 2          NaT
# 3          NaT
# 4          NaT
# Name: data_da_ultima_compra, dtype: datetime64[ns]

# %%
df1["data_da_ultima_compra"].dtype
# Out:
# dtype('<M8[ns]')

# %% [markdown]
# #### Padronização da Coluna "telefone_celular"

# %%
df1["telefone_celular"].head()
# Out:
# 0    (85) 16400-0408
# 1      31 87481-2231
# 2    (11) 93064-3172
# 3    (11) 42963-8044
# 4      11 60767-0256
# Name: telefone_celular, dtype: object

# %%
def padronizar_telefone(telefone, apenas_digitos=False):
    if pd.isna(telefone):
        return None
    
    numero_limpo = re.sub(r'\D', '', str(telefone))
    
    if len(numero_limpo) == 13 and numero_limpo.startswith('55'):
        return f"+{numero_limpo[:2]} ({numero_limpo[2:4]}) {numero_limpo[4:9]}-{numero_limpo[9:]}"
    elif len(numero_limpo) == 11:
        return f"({numero_limpo[:2]}) {numero_limpo[2:7]}-{numero_limpo[7:]}"
    elif len(numero_limpo) == 10:
        return f"({numero_limpo[:2]}) {numero_limpo[2:6]}-{numero_limpo[6:]}"
    else:
        return numero_limpo

# %%
df1['telefone_celular'] = df1['telefone_celular'].apply(padronizar_telefone)

# %%
df1["telefone_celular"].head()
# Out:
# 0    (85) 16400-0408
# 1    (31) 87481-2231
# 2    (11) 93064-3172
# 3    (11) 42963-8044
# 4    (11) 60767-0256
# Name: telefone_celular, dtype: object

# %%
# Convertendo para string

df1['telefone_celular'] = df1['telefone_celular'].astype('string')

# %%
df1["telefone_celular"].dtype
# Out:
# string[python]

# %% [markdown]
# #### Padronização da Coluna "cep"

# %%
df1["cep"].head()
# Out:
# 0     04397312
# 1       123456
# 2    81093-112
# 3     80681606
# 4    34867-654
# Name: cep, dtype: object

# %%
def padronizar_cep(cep):
    if pd.isna(cep):
        return pd.NA
    
    cep_limpo = re.sub(r'\D', '', str(cep))
    cep_limpo = cep_limpo.zfill(8)

    if len(cep_limpo) == 8:
        return f"{cep_limpo[:5]}-{cep_limpo[5:]}"
    
    return pd.NA

# %%
df1['cep'] = df1['cep'].apply(padronizar_cep)

# %%
df1["cep"] = df1["cep"].astype("string")

# %%
df1["cep"].head()
# Out:
# 0    04397-312
# 1    00123-456
# 2    81093-112
# 3    80681-606
# 4    34867-654
# Name: cep, dtype: string

# %%
df1["cep"].dtype
# Out:
# string[python]

# %% [markdown]
# #### Padronização da Coluna "endereco"

# %%
df1["endereco"].head()
# Out:
# 0                               NaN
# 1    rua principal, 935 - guarulhos
# 2      rua central, 633 - fortaleza
# 3     rua principal, 630 - brasilia
# 4       rua da paz, 673 - fortaleza
# Name: endereco, dtype: object

# %%
df1["endereco"].dtype
# Out:
# dtype('O')

# %%
# Convertendo de Object para String

df1["endereco"] = df1["endereco"].astype("string")

# %%
df1["endereco"].dtype
# Out:
# string[python]

# %%
df1["endereco"].isna().sum()
# Out:
# np.int64(5220)

# %%
# Checando a qualidade e a consistência estrutural

df1["endereco"].str.len().describe()
# Out:
# count   47280
# mean       29
# std         3
# min        21
# 25%        26
# 50%        28
# 75%        30
# max        36
# Name: endereco, dtype: Float64

# %%
# Procurando caracteres inesperados

df1["endereco"].str.contains(r"[^a-z0-9\s\.,º°\-]", regex=True).sum()
# Out:
# np.int64(0)

# %%
# Procurando vírgulas duplicadas

df1["endereco"].str.contains(r",,", regex=True).sum()
# Out:
# np.int64(0)

# %%
# Vendo padrões de início (rua, avenida, travessa…)

df1["endereco"].str.extract(r"^([a-z]+)")
# Out:
#           0
# 0      <NA>
# 1       rua
# 2       rua
# 3       rua
# 4       rua
# ...     ...
# 52495   rua
# 52496   rua
# 52497   rua
# 52498   rua
# 52499   rua
#
# [52500 rows x 1 columns]

# %%
# Checando se todas tem número

df1["endereco"].str.contains(r"\d").mean()
# Out:
# np.float64(1.0)

# %%
df1["endereco"].head()
# Out:
# 0                              <NA>
# 1    rua principal, 935 - guarulhos
# 2      rua central, 633 - fortaleza
# 3     rua principal, 630 - brasilia
# 4       rua da paz, 673 - fortaleza
# Name: endereco, dtype: string

# %% [markdown]
# #### Padronização da Coluna "estado_uf"

# %%
df1["estado_uf"].tail()
# Out:
# 52495    SP
# 52496    SP
# 52497    PE
# 52498    SP
# 52499    RS
# Name: estado_uf, dtype: object

# %%
# Normalizando o texto

df1['estado_uf'] = (
    df1['estado_uf']
    .astype(str)
    .str.normalize('NFKD')
    .str.encode('ascii', errors='ignore')
    .str.decode('utf-8')
    .str.lower()
    .str.replace('.', '', regex=False)
    .str.strip()
    .str.replace(r'\s+', ' ', regex=True)
)

# %%
df1["estado_uf"].tail()
# Out:
# 52495    sp
# 52496    sp
# 52497    pe
# 52498    sp
# 52499    rs
# Name: estado_uf, dtype: object

# %%
# Mapeando os nomes dos estados

mapa_estados = {
    "acre": "AC",
    "alagoas": "AL",
    "amapa": "AP",
    "amazonas": "AM",
    "bahia": "BA",
    "ceara": "CE",
    "distrito federal": "DF",
    "espirito santo": "ES",
    "goias": "GO",
    "maranhao": "MA",
    "mato grosso": "MT",
    "mato grosso do sul": "MS",
    "minas gerais": "MG",
    "para": "PA",
    "paraiba": "PB",
    "parana": "PR",
    "pernambuco": "PE",
    "piaui": "PI",
    "rio de janeiro": "RJ",
    "rio grande do norte": "RN",
    "rio grande do sul": "RS",
    "rondonia": "RO",
    "roraima": "RR",
    "santa catarina": "SC",
    "sao paulo": "SP",
    "sergipe": "SE",
    "tocantins": "TO",
}

# %%
# Aplicando o mapeamento

df1['estado_uf'] = df1['estado_uf'].replace(mapa_estados).astype("string")

# %%
# Deixando as siglas em maiúsculas

df1['estado_uf'] = df1['estado_uf'].str.upper()

# %%
df1["estado_uf"].tail()
# Out:
# 52495    SP
# 52496    SP
# 52497    PE
# 52498    SP
# 52499    RS
# Name: estado_uf, dtype: string

# %%
df1["estado_uf"].dtype
# Out:
# string[python]

# %% [markdown]
# #### Padronização da Coluna "salario"

# %%
df1["salario"].head()
# Out:
# 0    Salário confidencial
# 1           Não informado
# 2                   12030
# 3                   12038
# 4                   14659
# Name: salario, dtype: object

# %%
def clean_salario(df, coluna="salario"):

    # Lista de valores que são considerados nulos
    valores_sem_salario = {
        "salário confidencial",
        "salario confidencial",
        "não informado",
        "nao informado",
        "nao_informado",
        "",
    }
    
    # Normalização inicial
    col = (
        df[coluna]
        .astype("string")
        .str.strip()
        .str.lower()
    )

    col = col.replace(valores_sem_salario, pd.NA)
    col_numerica = pd.to_numeric(col, errors="coerce")
    
    auditoria = df[
        col.isna() & ~df[coluna].astype("string").str.lower().isin(valores_sem_salario)
    ][[coluna]]
    
    df[coluna] = col_numerica.astype("Float64")
    
    return df, auditoria

# %%
df1, auditoria = clean_salario(df1, "salario")

# %%
df1["salario"].head()
# Out:
# 0    <NA>
# 1    <NA>
# 2   12030
# 3   12038
# 4   14659
# Name: salario, dtype: Float64

# %% [markdown]
# #### Padronização da Coluna "status_da_conta"

# %%
df1["status_da_conta"].head()
# Out:
# 0     suspenso
# 1        ativo
# 2            a
# 3      inativo
# 4    bloqueado
# Name: status_da_conta, dtype: object

# %%
def normalize_text(x):
    if pd.isna(x):
        return x
    x = str(x).lower().strip()
    x = unicodedata.normalize("NFKD", x).encode("ascii", "ignore").decode("utf-8")
    x = re.sub(r"\s+", " ", x)
    return x

map_status = {
    "ativo": "ativo",
    "a": "ativo",
    "inativo": "inativo",
    "in": "inativo",
    "suspenso": "suspenso",
    "s": "suspenso",
    "bloqueado": "bloqueado",
}

boolean_true = {"true", "verdadeiro"}
boolean_false = {"false", "falso"}

def clean_status(value):
    v = normalize_text(value)

    if pd.isna(v) or not isinstance(v, str):
        return pd.NA

    if v.isdigit():
        return "ativo" if v == "1" else pd.NA

    if v in boolean_true:
        return "ativo"
    if v in boolean_false:
        return "inativo"

    return map_status.get(v, pd.NA)

# %%
df1["status_da_conta"] = df1["status_da_conta"].apply(clean_status).astype("string")

# %%
df1["status_da_conta"].head()
# Out:
# 0     suspenso
# 1        ativo
# 2        ativo
# 3      inativo
# 4    bloqueado
# Name: status_da_conta, dtype: string

# %% [markdown]
# #### Padronização da Coluna "score_de_credito"

# %%
df1["score_de_credito"].head()
# Out:
# 0    852
# 1    517
# 2    428
# 3    662
# 4    375
# Name: score_de_credito, dtype: object

# %%
def normalize_score(x):
    if pd.isna(x):
        return x
    x = str(x).lower().strip()
    x = unicodedata.normalize("NFKD", x).encode("ascii", "ignore").decode("utf-8")
    x = re.sub(r"\s+", " ", x)
    return x

map_status = {
    "excelente": 800,
    "bom": 700,
    "ruim": 400
}

def clean_score(value):
    if isinstance(value, (int, float)) and not pd.isna(value):
        return value

    if pd.isna(value):
        return pd.NA

    v = normalize_score(value)

    if pd.isna(v):
        return pd.NA

    if re.fullmatch(r"\d+", v):
        return int(v)

    return map_status.get(v, pd.NA)

# %%
df1["score_de_credito"] = df1["score_de_credito"].apply(clean_score).astype("Int64")

# %%
df1["score_de_credito"].head()
# Out:
# 0    852
# 1    517
# 2    428
# 3    662
# 4    375
# Name: score_de_credito, dtype: Int64

# %% [markdown]
# #### Padronização da Coluna "produto_favorito"

# %%
df1["produto_favorito"].sample(5, random_state=4)
# Out:
# 11869           monitor
# 46312                tv
# 14616    fone de ouvido
# 36637        smartwatch
# 46630        smartphone
# Name: produto_favorito, dtype: object

# %%
df1['produto_favorito'] = (
    df1['produto_favorito']
    .str.replace(r'-\s*produto$', '', regex=True)
    .str.strip()
)

# %%
df1["produto_favorito"].unique()
# Out:
# array(['monitor', 'teclado', 'notebook', 'camera', 'mouse',
#        'fone de ouvido', 'smartphone', 'tablet', nan, 'smartwatch', 'tv'],
#       dtype=object)

# %%
df1['produto_favorito'] = (
    df1['produto_favorito']
    .replace(['nan', 'None', 'null', ''], np.nan)
    .astype('string')
    .str.strip()
)

# %%
df1["produto_favorito"].unique()
# Out:
# <StringArray>
# [       'monitor',        'teclado',       'notebook',         'camera',
#           'mouse', 'fone de ouvido',     'smartphone',         'tablet',
#              <NA>,     'smartwatch',             'tv']
# Length: 11, dtype: string

# %%
df1["produto_favorito"].head()
# Out:
# 0     monitor
# 1     monitor
# 2     teclado
# 3    notebook
# 4      camera
# Name: produto_favorito, dtype: string

# %% [markdown]
# #### Padronização da Coluna "valor_total_gasto"

# %%
df1["valor_total_gasto"].tail()
# Out:
# 52495    2090.78
# 52496     R$2500
# 52497     718.06
# 52498    1218.89
# 52499    3468.76
# Name: valor_total_gasto, dtype: object

# %%
mask = ~df1["valor_total_gasto"].astype(str).str.replace(r"[0-9.,]", "", regex=True).str.strip().eq("")
df1.loc[mask, "valor_total_gasto"].unique()
# Out:
# array(['Zero', 'Muito alto', 'Baixo', 'R$ 1.250,50', nan, 'R$2500'],
#       dtype=object)

# %%
def limpar_valor(valor):
    if pd.isna(valor):
        return np.nan
    valor = str(valor).replace(" ", "").replace(".", "").replace(",", ".")
    try:
        return float(valor)
    except ValueError:
        return np.nan

# %%
df1["valor_total_gasto"] = df1["valor_total_gasto"].apply(limpar_valor)

# %%
df1["valor_total_gasto"].tail()
# Out:
# 52495   209078
# 52496      NaN
# 52497    71806
# 52498   121889
# 52499   346876
# Name: valor_total_gasto, dtype: float64

# %%
df1["valor_total_gasto"].dtype
# Out:
# dtype('float64')

# %% [markdown]
# #### Padronização da Coluna "categoria_cliente"

# %%
df1["categoria_cliente"].head()
# Out:
# 0        ouro
# 1    diamante
# 2        ouro
# 3     platina
# 4        ouro
# Name: categoria_cliente, dtype: object

# %%
df1["categoria_cliente"].unique()
# Out:
# array(['ouro', 'diamante', 'platina', 'bronze', 'prata', 'gold',
#        'premium', 'vip', nan], dtype=object)

# %%
def diagnostico_coluna(df, coluna, n=60):
    ultimos = df[coluna].tail(n)
    tipos = set(type(x) for x in ultimos)
    tem_string_nan = any(str(x).lower() == "nan" for x in ultimos)
    dtype = df[coluna].dtype
    print(f"Diagnóstico da coluna '{coluna}':")
    print("Tipos encontrados nos últimos", n, "valores:", tipos)
    print("Existe string 'nan'? ", tem_string_nan)
    print("dtype da coluna:", dtype)

# %%
diagnostico_coluna(df1, "categoria_cliente")
# Out:
# Diagnóstico da coluna 'categoria_cliente':
# Tipos encontrados nos últimos 60 valores: {<class 'str'>, <class 'float'>}
# Existe string 'nan'?  True
# dtype da coluna: object

# %%
df1["categoria_cliente"] = df1["categoria_cliente"].replace(["nan", "NaN", "None", ""], np.nan)

# %%
df1["categoria_cliente"] = df1["categoria_cliente"].astype("string").replace(["nan", "NaN", "None", ""], pd.NA)

# %%
diagnostico_coluna(df1, "categoria_cliente")
# Out:
# Diagnóstico da coluna 'categoria_cliente':
# Tipos encontrados nos últimos 60 valores: {<class 'pandas._libs.missing.NAType'>, <class 'str'>}
# Existe string 'nan'?  False
# dtype da coluna: string

# %%
df1["categoria_cliente"].tail()
# Out:
# 52495     bronze
# 52496     bronze
# 52497     bronze
# 52498       ouro
# 52499    platina
# Name: categoria_cliente, dtype: string

# %% [markdown]
# #### Padronização da Coluna "ativo"

# %%
df1["ativo"].tail()
# Out:
# 52495    n
# 52496    s
# 52497    n
# 52498    s
# 52499    n
# Name: ativo, dtype: object

# %%
df1["ativo"].unique()
# Out:
# array(['ativo', 's', 'n', nan, 'nao', 'inativo', 'true', '1', 'false',
#        'sim', '0'], dtype=object)

# %%
def padronizar_ativo(x):
    if pd.isna(x):
        return pd.NA
    x = str(x).strip().lower()
    if x in {"ativo", "s", "sim", "true", "1"}:
        return "ativo"
    if x in {"inativo", "n", "nao", "não", "false", "0"}:
        return "inativo"
    return pd.NA

# %%
df1["ativo"] = df1["ativo"].apply(padronizar_ativo).astype("string")

# %%
df1["ativo"].unique()
# Out:
# <StringArray>
# ['ativo', 'inativo', <NA>]
# Length: 3, dtype: string

# %%
df1["ativo"].head()
# Out:
# 0      ativo
# 1      ativo
# 2    inativo
# 3    inativo
# 4    inativo
# Name: ativo, dtype: string

# %% [markdown]
# #### Padronização da Coluna "regional_zona"

# %%
df1["regional_zona"].head()
# Out:
# 0           norte
# 1    centro-oeste
# 2    centro-oeste
# 3          centro
# 4          centro
# Name: regional_zona, dtype: object

# %%
df1["regional_zona"].unique()
# Out:
# array(['norte', 'centro-oeste', 'centro', 'sul', 'leste', 'oeste', nan],
#       dtype=object)

# %%
def padronizar_regional_zona(x):
    if pd.isna(x):
        return pd.NA
    x = str(x).strip().lower()
    x = unicodedata.normalize("NFKD", x).encode("ascii", "ignore").decode("utf-8")
    x = x.replace("-", "_")
    mapa = {
        "norte": "norte",
        "sul": "sul",
        "leste": "leste",
        "oeste": "oeste",
        "centro": "centro",
        "centro_oeste": "centro-oeste",
        "centro-oeste": "centro-oeste"
    }
    return mapa.get(x, x)

# %%
df1["regional_zona"] = df1["regional_zona"].apply(padronizar_regional_zona).astype("string")

# %%
df1["regional_zona"].unique()
# Out:
# <StringArray>
# ['norte', 'centro-oeste', 'centro', 'sul', 'leste', 'oeste', <NA>]
# Length: 7, dtype: string

# %%
df1["regional_zona"].head()
# Out:
# 0           norte
# 1    centro-oeste
# 2    centro-oeste
# 3          centro
# 4          centro
# Name: regional_zona, dtype: string

# %% [markdown]
# ## Limpando os Dados

# %% [markdown]
# - remover duplicatas
# - tratar valores faltantes
# - corrigir inconsistências
# - tratar outliers
# - validar regras de negócio

# %% [markdown]
# ### Tratamento de Valores Ausentes

# %% [markdown]
# #### Deletando Colunas Vazias

# %%
df1 = df1.drop(columns=["unnamed_16"])

# %%
df1.head()
# Out:
#    id_cliente   nome_completo      nome_limpo                      email  \
# 0           1       Ana Silva       ana silva        ana.silva@yahoo.com
# 1           2     Carla Souza     carla souza                       <NA>
# 2           3       Ana Costa       ana costa      ana.costa@hotmail.com
# 3           4  Mariana Santos  mariana santos  mariana.santos@bol.com.br
# 4           5     Maria Silva     maria silva    maria.silva@hotmail.com
#
#    idade data_de_nascimento telefone_celular        cep  \
# 0     56                NaT  (85) 16400-0408  04397-312
# 1     69         1950-10-18  (31) 87481-2231  00123-456
# 2     46                NaT  (11) 93064-3172  81093-112
# 3     32         1976-06-08  (11) 42963-8044  80681-606
# 4     60         2001-03-19  (11) 60767-0256  34867-654
#
#                          endereco estado_uf  salario status_da_conta  \
# 0                            <NA>        CE     <NA>        suspenso
# 1  rua principal, 935 - guarulhos        PA     <NA>           ativo
# 2    rua central, 633 - fortaleza        RJ    12030           ativo
# 3   rua principal, 630 - brasilia        RS    12038         inativo
# 4     rua da paz, 673 - fortaleza        BA    14659       bloqueado
#
#    score_de_credito produto_favorito data_da_ultima_compra  valor_total_gasto  \
# 0               852          monitor            2024-09-30             449503
# 1               517          monitor                   NaT             675127
# 2               428          teclado                   NaT             690093
# 3               662         notebook                   NaT             374336
# 4               375           camera                   NaT              90773
#
#   categoria_cliente obs_comentarios    ativo regional_zona
# 0              ouro             NaN    ativo         norte
# 1          diamante             NaN    ativo  centro-oeste
# 2              ouro             NaN  inativo  centro-oeste
# 3           platina             NaN  inativo        centro
# 4              ouro             NaN  inativo        centro

# %% [markdown]
# #### Valores Ausentes

# %%
df1.isna().sum()
# Out:
# id_cliente                   0
# nome_completo                0
# nome_limpo                   0
# email                     9732
# idade                     4900
# data_de_nascimento        6507
# telefone_celular          2097
# cep                       2163
# endereco                  5220
# estado_uf                    0
# salario                   9330
# status_da_conta           2139
# score_de_credito          6925
# produto_favorito          6230
# data_da_ultima_compra    36664
# valor_total_gasto         7355
# categoria_cliente         1162
# obs_comentarios          40034
# ativo                     1096
# regional_zona             2677
# dtype: int64

# %%
len(df1)
# Out:
# 52500

# %%
# Deletando a coluna de observações

df1 = df1.drop(columns=["obs_comentarios"])

# %%
df1.head()
# Out:
#    id_cliente   nome_completo      nome_limpo                      email  \
# 0           1       Ana Silva       ana silva        ana.silva@yahoo.com
# 1           2     Carla Souza     carla souza                       <NA>
# 2           3       Ana Costa       ana costa      ana.costa@hotmail.com
# 3           4  Mariana Santos  mariana santos  mariana.santos@bol.com.br
# 4           5     Maria Silva     maria silva    maria.silva@hotmail.com
#
#    idade data_de_nascimento telefone_celular        cep  \
# 0     56                NaT  (85) 16400-0408  04397-312
# 1     69         1950-10-18  (31) 87481-2231  00123-456
# 2     46                NaT  (11) 93064-3172  81093-112
# 3     32         1976-06-08  (11) 42963-8044  80681-606
# 4     60         2001-03-19  (11) 60767-0256  34867-654
#
#                          endereco estado_uf  salario status_da_conta  \
# 0                            <NA>        CE     <NA>        suspenso
# 1  rua principal, 935 - guarulhos        PA     <NA>           ativo
# 2    rua central, 633 - fortaleza        RJ    12030           ativo
# 3   rua principal, 630 - brasilia        RS    12038         inativo
# 4     rua da paz, 673 - fortaleza        BA    14659       bloqueado
#
#    score_de_credito produto_favorito data_da_ultima_compra  valor_total_gasto  \
# 0               852          monitor            2024-09-30             449503
# 1               517          monitor                   NaT             675127
# 2               428          teclado                   NaT             690093
# 3               662         notebook                   NaT             374336
# 4               375           camera                   NaT              90773
#
#   categoria_cliente    ativo regional_zona
# 0              ouro    ativo         norte
# 1          diamante    ativo  centro-oeste
# 2              ouro  inativo  centro-oeste
# 3           platina  inativo        centro
# 4              ouro  inativo        centro

# %% [markdown]
# #### Duplicatas

# %%
df1.duplicated().sum()
# Out:
# np.int64(2500)

# %%
df1.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 52495     True
# 52496     True
# 52497     True
# 52498     True
# 52499     True
# Length: 52500, dtype: bool

# %%
df1[df1.duplicated()]
# Out:
#        id_cliente     nome_completo        nome_limpo  \
# 50000       31362     Maria   Gomes       maria gomes
# 50001       16722     Rafael Santos     rafael santos
# 50002       36789  Claudia Oliveira  claudia oliveira
# 50003       22819       Pedro Souza       pedro souza
# 50004       24795       Maria Souza       maria souza
# ...           ...               ...               ...
# 52495       26846    Paulo Ferreira    paulo ferreira
# 52496       45552    Patricia Silva    patricia silva
# 52497       25412        João Alves        joao alves
# 52498       44726       Lucia Gomes       lucia gomes
# 52499       30012  Carlos Rodrigues  carlos rodrigues
#
#                               email  idade data_de_nascimento  \
# 50000      maria...gomes@uol.com.br     24         1999-10-24
# 50001      rafael.santos@bol.com.br     76         1985-11-06
# 50002  claudia.oliveira@hotmail.com     42         1956-01-22
# 50003        pedro.souza@bol.com.br     35         1960-12-08
# 50004         maria.souza@yahoo.com     70         1958-09-24
# ...                             ...    ...                ...
# 52495    paulo.ferreira@outlook.com     38         1996-09-21
# 52496     patricia.silva@uol.com.br     53         1968-11-09
# 52497         joão.alves@uol.com.br     18         1968-06-09
# 52498         lucia.gomes@gmail.com     75         1990-02-15
# 52499  carlos.rodrigues@outlook.com     35         1970-01-16
#
#       telefone_celular        cep                              endereco  \
# 50000  (21) 61369-1296  28607-746  rua das flores, 401 - belo horizonte
# 50001  (11) 62613-2573  85267-384     rua central, 546 - belo horizonte
# 50002  (11) 49487-5313  88836-534       rua das flores, 172 - sao paulo
# 50003  (11) 99999-9999  87846-239               rua central, 80 - belem
# 50004  (85) 64265-6137  04704-402       rua central, 557 - porto alegre
# ...                ...        ...                                   ...
# 52495  (11) 02698-1177  55227-309  rua das flores, 941 - rio de janeiro
# 52496  (11) 99999-9999  05529-465     rua central, 860 - rio de janeiro
# 52497              123  60427-184             rua da paz, 51 - brasilia
# 52498  (11) 58751-5945  71609-249          rua da paz, 2 - porto alegre
# 52499  (11) 58549-1317  02218-308          rua das flores, 372 - manaus
#
#       estado_uf  salario status_da_conta  score_de_credito produto_favorito  \
# 50000        RJ     5506           ativo               849            mouse
# 50001        RJ     6995         inativo              <NA>          teclado
# 50002       NAN     8966        suspenso               429       smartphone
# 50003        BA    14658        suspenso              <NA>          monitor
# 50004        MG    11155       bloqueado               561          monitor
# ...         ...      ...             ...               ...              ...
# 52495        SP    14486        suspenso               550               tv
# 52496        SP     <NA>         inativo               836         notebook
# 52497        PE     6930       bloqueado               866          teclado
# 52498        SP     9779           ativo              <NA>           camera
# 52499        RS     8644       bloqueado               381            mouse
#
#       data_da_ultima_compra  valor_total_gasto categoria_cliente    ativo  \
# 50000                   NaT             364034           platina  inativo
# 50001            2024-10-03             323128             prata  inativo
# 50002                   NaT             232292             prata  inativo
# 50003                   NaT              74335             prata  inativo
# 50004            2024-12-05             391055           platina     <NA>
# ...                     ...                ...               ...      ...
# 52495            2024-07-13             209078            bronze  inativo
# 52496                   NaT                NaN            bronze    ativo
# 52497                   NaT              71806            bronze  inativo
# 52498                   NaT             121889              ouro    ativo
# 52499            2024-09-09             346876           platina  inativo
#
#       regional_zona
# 50000         norte
# 50001  centro-oeste
# 50002         norte
# 50003           sul
# 50004         norte
# ...             ...
# 52495           sul
# 52496        centro
# 52497         norte
# 52498         norte
# 52499           sul
#
# [2500 rows x 19 columns]

# %%
df1 = df1.drop_duplicates()

# %%
# Conferindo se as duplicatas foram removidas
df1[df1.duplicated()]
# Out:
# Empty DataFrame
# Columns: [id_cliente, nome_completo, nome_limpo, email, idade, data_de_nascimento, telefone_celular, cep, endereco, estado_uf, salario, status_da_conta, score_de_credito, produto_favorito, data_da_ultima_compra, valor_total_gasto, categoria_cliente, ativo, regional_zona]
# Index: []

# %%
df1.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Enriquecer/Transformar os Dados

# %% [markdown]
# - criar novas colunas
# - fazer joins
# - preparar para modelagem
